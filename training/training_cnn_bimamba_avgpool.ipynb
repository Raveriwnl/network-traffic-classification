# %% [markdown]
# # Huawei CNN-BiMamba AvgPool Training
#
# 使用 datasets/processed/huawei/huawei_5s_1000bins_features.npz 进行训练，包含：
# - 数据集划分 (train/val/test = 0.7/0.15/0.15)
# - 对重尾非负特征先做 log1p，再做 RobustScaler 预处理
# - 使用平均值池化替换注意力池化的 CNN-BiMamba 模型训练与评估
# - 最优模型保存到 models/

# %%
import importlib
import random
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from sklearn.metrics import ConfusionMatrixDisplay, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from torch.optim import AdamW
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.profiler import ProfilerActivity, profile
from torch.utils.data import DataLoader, TensorDataset

if (Path.cwd() / "training").exists():
    sys.path.append(str(Path.cwd() / "training"))
elif Path.cwd().name == "training":
    sys.path.append(str(Path.cwd()))

CONFIG = {
    "seed": 42,
    "dataset_path": "../datasets/processed/huawei/huawei_5s_1000bins_features.npz",
    "model_module": "cnn_bimamba_avgpool",
    "model_builder": "build_cnn_bimamba_avgpool_model",
    "model_kwargs": {
        "num_mamba_layers": 1,
        "mamba_dropout": 0.20,
        "stem_dropout": 0.15,
        "head_dropout": 0.35,
        "drop_path_rate": 0.15,
    },
    "train_ratio": 0.70,
    "val_ratio": 0.15,
    "test_ratio": 0.15,
    "batch_size": 64,
    "epochs": 120,
    "learning_rate": 6e-4,
    "weight_decay": 3e-4,
    "scheduler_factor": 0.5,
    "scheduler_patience": 6,
    "scheduler_min_lr": 1e-5,
    "early_stop_patience": 18,
    "label_smoothing": 0.04,
    "mixup_alpha": 0.20,
    "mixup_prob": 0.40,
    "input_noise_std": 0.004,
    "time_mask_prob": 0.10,
    "time_mask_ratio": 0.04,
    "grad_clip_norm": 1.0,
    "use_sam": True,
    "sam_rho": 0.05,
    "use_ema": True,
    "ema_decay": 0.999,
    "eval_with_ema": True,
    "save_ema_checkpoint": True,
    "best_metric": "val_loss",
    "report_clean_train_metrics": True,
    "model_save_name": "huawei_cnn_bimamba_avgpool_best.pt",
    "eval_model_path": "models/huawei_cnn_bimamba_avgpool_best.pt",
    "log1p_features": [
        "pkt_count",
        "pkt_len_mean",
        "pkt_len_std",
        "last_pkt_global_iat",
        "uplink_pkt_len_sum",
        "downlink_pkt_len_sum",
        "uplink_pkt_count",
        "downlink_pkt_count",
    ],
}

if not np.isclose(CONFIG["train_ratio"] + CONFIG["val_ratio"] + CONFIG["test_ratio"], 1.0):
    raise ValueError("train_ratio + val_ratio + test_ratio must equal 1.0")

SEED = int(CONFIG["seed"])
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.set_device(7)
    torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
print("Dataset:", CONFIG["dataset_path"])
print("Model:", f"{CONFIG['model_module']}.{CONFIG['model_builder']}")
print("Model kwargs:", CONFIG["model_kwargs"])
print("Evaluation checkpoint:", CONFIG["eval_model_path"])
print("Generalization config:", {
    "label_smoothing": CONFIG["label_smoothing"],
    "mixup": (CONFIG["mixup_alpha"], CONFIG["mixup_prob"]),
    "noise_std": CONFIG["input_noise_std"],
    "time_mask": (CONFIG["time_mask_prob"], CONFIG["time_mask_ratio"]),
    "sam": (CONFIG["use_sam"], CONFIG["sam_rho"]),
    "ema": (CONFIG["use_ema"], CONFIG["ema_decay"]),
    "report_clean_train_metrics": CONFIG["report_clean_train_metrics"],
    "log1p_features": CONFIG["log1p_features"],
})
# Out:
# Using device: cuda
# Dataset: ../datasets/processed/huawei/huawei_5s_1000bins_features.npz
# Model: cnn_bimamba_avgpool.build_cnn_bimamba_avgpool_model
# Model kwargs: {'num_mamba_layers': 1, 'mamba_dropout': 0.2, 'stem_dropout': 0.15, 'head_dropout': 0.35, 'drop_path_rate': 0.15}
# Evaluation checkpoint: models/huawei_cnn_bimamba_avgpool_best.pt
# Generalization config: {'label_smoothing': 0.04, 'mixup': (0.2, 0.4), 'noise_std': 0.004, 'time_mask': (0.1, 0.04), 'sam': (True, 0.05), 'ema': (True, 0.999), 'report_clean_train_metrics': True, 'log1p_features': ['pkt_count', 'pkt_len_mean', 'pkt_len_std', 'last_pkt_global_iat', 'uplink_pkt_len_sum', 'downlink_pkt_len_sum', 'uplink_pkt_count', 'downlink_pkt_count']}

# %%
data_path = Path(CONFIG["dataset_path"])
if not data_path.exists():
    raise FileNotFoundError(f"Cannot find dataset file: {data_path}")

data = np.load(data_path, allow_pickle=True)
X = data["X"].astype(np.float32)
y = data["y"].astype(np.int64)
classes = data["classes"] if "classes" in data.files else np.unique(y)
feature_names = (
    data["feature_names"].astype(str)
    if "feature_names" in data.files
    else np.array([f"feature_{i}" for i in range(X.shape[-1])], dtype=str)
)

print("X shape:", X.shape)
print("y shape:", y.shape)
print("num classes:", len(classes), classes)
print("feature names:", feature_names.tolist())

test_ratio = float(CONFIG["test_ratio"])
val_ratio = float(CONFIG["val_ratio"])
remaining_ratio = 1.0 - test_ratio
val_ratio_within_temp = val_ratio / remaining_ratio

X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=test_ratio, random_state=SEED, stratify=y
)

X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=val_ratio_within_temp, random_state=SEED, stratify=y_temp
)

print("Train shape:", X_train.shape, y_train.shape)
print("Val shape:", X_val.shape, y_val.shape)
print("Test shape:", X_test.shape, y_test.shape)

num_features = X_train.shape[-1]
feature_name_to_idx = {name: idx for idx, name in enumerate(feature_names.tolist())}
missing_log1p_features = [name for name in CONFIG["log1p_features"] if name not in feature_name_to_idx]
if missing_log1p_features:
    raise ValueError(f"Unknown log1p features: {missing_log1p_features}")

log1p_feature_indices = [feature_name_to_idx[name] for name in CONFIG["log1p_features"]]

def apply_log1p_transform(x3d, feature_indices):
    transformed = x3d.copy()
    if feature_indices:
        transformed[:, :, feature_indices] = np.log1p(
            np.clip(transformed[:, :, feature_indices], a_min=0.0, a_max=None)
        )
    return transformed.astype(np.float32)

X_train_log = apply_log1p_transform(X_train, log1p_feature_indices)
X_val_log = apply_log1p_transform(X_val, log1p_feature_indices)
X_test_log = apply_log1p_transform(X_test, log1p_feature_indices)

scaler = RobustScaler(with_centering=True, with_scaling=True)
scaler.fit(X_train_log.reshape(-1, num_features))

def apply_scaler(x3d):
    x2d = scaler.transform(x3d.reshape(-1, num_features))
    return x2d.reshape(x3d.shape).astype(np.float32)

X_train_scaled = apply_scaler(X_train_log)
X_val_scaled = apply_scaler(X_val_log)
X_test_scaled = apply_scaler(X_test_log)

print("Applied log1p to features:", CONFIG["log1p_features"])
print("Scaled train mean (approx):", X_train_scaled.mean(axis=(0, 1)))
# Out:
# X shape: (3200, 1000, 10)
# y shape: (3200,)
# num classes: 8 ['cloud_game' 'live' 'meeting' 'message' 'openlive' 'phone_game'
#  'short_video' 'video']
# feature names: ['pkt_count', 'pkt_len_mean', 'pkt_len_std', 'last_pkt_global_iat', 'time_offset_mean_norm', 'uplink_ratio', 'uplink_pkt_len_sum', 'downlink_pkt_len_sum', 'uplink_pkt_count', 'downlink_pkt_count']
# Train shape: (2239, 1000, 10) (2239,)
# Val shape: (481, 1000, 10) (481,)
# Test shape: (480, 1000, 10) (480,)
# Applied log1p to features: ['pkt_count', 'pkt_len_mean', 'pkt_len_std', 'last_pkt_global_iat', 'uplink_pkt_len_sum', 'downlink_pkt_len_sum', 'uplink_pkt_count', 'downlink_pkt_count']
# Scaled train mean (approx): [0.3640149  1.3131924  0.55895454 0.27521262 0.10122527 0.11323868
#  1.0439136  0.8864544  0.23788728 0.18675824]

# %%
class SAM(torch.optim.Optimizer):
    def __init__(self, params, base_optimizer, rho=0.05, **kwargs):
        if rho < 0.0:
            raise ValueError(f"Invalid rho value: {rho}")
        defaults = dict(rho=rho, **kwargs)
        super().__init__(params, defaults)
        self.base_optimizer = base_optimizer(self.param_groups, **kwargs)
        self.param_groups = self.base_optimizer.param_groups
        self.defaults.update(self.base_optimizer.defaults)

    @torch.no_grad()
    def first_step(self, zero_grad=False):
        grad_norm = self._grad_norm()
        if grad_norm == 0:
            if zero_grad:
                self.zero_grad()
            return
        for group in self.param_groups:
            scale = group["rho"] / (grad_norm + 1e-12)
            for p in group["params"]:
                if p.grad is None:
                    continue
                e_w = p.grad * scale.to(p)
                p.add_(e_w)
                self.state[p]["e_w"] = e_w
        if zero_grad:
            self.zero_grad()

    @torch.no_grad()
    def second_step(self, zero_grad=False):
        for group in self.param_groups:
            for p in group["params"]:
                if p.grad is None:
                    continue
                p.sub_(self.state[p].get("e_w", 0.0))
        self.base_optimizer.step()
        if zero_grad:
            self.zero_grad()

    @torch.no_grad()
    def step(self, closure=None):
        if closure is None:
            raise RuntimeError("SAM requires closure-based step, use first_step/second_step.")
        loss = closure()
        self.first_step(zero_grad=True)
        closure()
        self.second_step()
        return loss

    def _grad_norm(self):
        shared_device = self.param_groups[0]["params"][0].device
        norms = []
        for group in self.param_groups:
            for p in group["params"]:
                if p.grad is not None:
                    norms.append(p.grad.norm(p=2).to(shared_device))
        if not norms:
            return torch.tensor(0.0, device=shared_device)
        return torch.norm(torch.stack(norms), p=2)


num_classes = len(np.unique(y))
model_module = importlib.import_module(CONFIG["model_module"])
model_builder = getattr(model_module, CONFIG["model_builder"])
model = model_builder(
    input_shape=X_train_scaled.shape[1:],
    num_classes=num_classes,
    **CONFIG["model_kwargs"],
).to(device)

criterion = nn.CrossEntropyLoss(label_smoothing=float(CONFIG["label_smoothing"]))

if bool(CONFIG.get("use_sam", False)):
    optimizer = SAM(
        model.parameters(),
        AdamW,
        rho=float(CONFIG["sam_rho"]),
        lr=float(CONFIG["learning_rate"]),
        weight_decay=float(CONFIG["weight_decay"]),
    )
else:
    optimizer = AdamW(
        model.parameters(),
        lr=float(CONFIG["learning_rate"]),
        weight_decay=float(CONFIG["weight_decay"]),
    )

scheduler = ReduceLROnPlateau(
    optimizer,
    mode="min",
    factor=float(CONFIG["scheduler_factor"]),
    patience=int(CONFIG["scheduler_patience"]),
    min_lr=float(CONFIG["scheduler_min_lr"]),
)

models_dir = Path("models")
models_dir.mkdir(parents=True, exist_ok=True)
best_model_path = models_dir / str(CONFIG["model_save_name"])

train_dataset = TensorDataset(torch.from_numpy(X_train_scaled).float(), torch.from_numpy(y_train).long())
val_dataset = TensorDataset(torch.from_numpy(X_val_scaled).float(), torch.from_numpy(y_val).long())
test_dataset = TensorDataset(torch.from_numpy(X_test_scaled).float(), torch.from_numpy(y_test).long())

batch_size = int(CONFIG["batch_size"])
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)


class ModelEMA:
    def __init__(self, model, decay=0.999):
        self.decay = float(decay)
        self.shadow = {}
        self.backup = {}
        for name, param in model.named_parameters():
            if param.requires_grad:
                self.shadow[name] = param.detach().clone()

    @torch.no_grad()
    def update(self, model):
        for name, param in model.named_parameters():
            if not param.requires_grad:
                continue
            self.shadow[name].mul_(self.decay).add_(param.detach(), alpha=1.0 - self.decay)

    @torch.no_grad()
    def apply_shadow(self, model):
        self.backup = {}
        for name, param in model.named_parameters():
            if not param.requires_grad:
                continue
            self.backup[name] = param.detach().clone()
            param.data.copy_(self.shadow[name].data)

    @torch.no_grad()
    def restore(self, model):
        for name, param in model.named_parameters():
            if not param.requires_grad:
                continue
            if name in self.backup:
                param.data.copy_(self.backup[name].data)
        self.backup = {}


def apply_time_mask(xb, mask_prob=0.2, mask_ratio=0.08):
    if mask_prob <= 0 or mask_ratio <= 0:
        return xb
    if np.random.rand() > mask_prob:
        return xb

    batch_size, seq_len, _ = xb.shape
    mask_len = max(1, int(seq_len * mask_ratio))
    starts = torch.randint(0, seq_len - mask_len + 1, (batch_size,), device=xb.device)

    for index, start in enumerate(starts):
        xb[index, start : start + mask_len, :] = 0.0
    return xb


def mixup_batch(xb, yb, alpha=0.2):
    if alpha <= 0:
        return xb, yb, yb, 1.0
    lam = np.random.beta(alpha, alpha)
    index = torch.randperm(xb.size(0), device=xb.device)
    mixed_xb = lam * xb + (1 - lam) * xb[index]
    y_a, y_b = yb, yb[index]
    return mixed_xb, y_a, y_b, lam


def run_epoch(model, loader, criterion, optimizer=None, apply_augment=False, apply_mixup=False, ema=None):
    is_train = optimizer is not None
    model.train() if is_train else model.eval()

    running_loss = 0.0
    correct = 0
    total = 0
    use_sam = is_train and bool(CONFIG.get("use_sam", False)) and hasattr(optimizer, "first_step")

    for xb, yb in loader:
        xb = xb.to(device)
        yb = yb.to(device)
        use_mixup = False

        if is_train:
            optimizer.zero_grad()

            if apply_augment:
                noise_std = float(CONFIG["input_noise_std"])
                if noise_std > 0:
                    xb = xb + torch.randn_like(xb) * noise_std
                xb = apply_time_mask(
                    xb,
                    mask_prob=float(CONFIG["time_mask_prob"]),
                    mask_ratio=float(CONFIG["time_mask_ratio"]),
                )

            if apply_mixup:
                use_mixup = np.random.rand() < float(CONFIG["mixup_prob"])
                if use_mixup:
                    xb, y_a, y_b, lam = mixup_batch(xb, yb, alpha=float(CONFIG["mixup_alpha"]))

        if is_train and use_sam:
            logits = model(xb)
            loss = lam * criterion(logits, y_a) + (1 - lam) * criterion(logits, y_b) if use_mixup else criterion(logits, yb)
            loss.backward()

            clip_norm = float(CONFIG["grad_clip_norm"])
            if clip_norm > 0:
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=clip_norm)
            optimizer.first_step(zero_grad=True)

            logits_second = model(xb)
            loss_second = (
                lam * criterion(logits_second, y_a) + (1 - lam) * criterion(logits_second, y_b)
                if use_mixup
                else criterion(logits_second, yb)
            )
            loss_second.backward()

            if clip_norm > 0:
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=clip_norm)
            optimizer.second_step(zero_grad=True)

            logits_for_metrics = logits.detach()
            loss_for_log = loss.detach()
        else:
            with torch.set_grad_enabled(is_train):
                logits = model(xb)
                loss = lam * criterion(logits, y_a) + (1 - lam) * criterion(logits, y_b) if is_train and use_mixup else criterion(logits, yb)
                if is_train:
                    loss.backward()
                    clip_norm = float(CONFIG["grad_clip_norm"])
                    if clip_norm > 0:
                        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=clip_norm)
                    optimizer.step()

            logits_for_metrics = logits.detach()
            loss_for_log = loss.detach()

        if is_train and ema is not None:
            ema.update(model)

        running_loss += loss_for_log.item() * yb.size(0)
        preds = logits_for_metrics.argmax(dim=1)
        correct += (preds == yb).sum().item()
        total += yb.size(0)

    return running_loss / total, correct / total


def get_current_lr(opt):
    if hasattr(opt, "base_optimizer"):
        return float(opt.base_optimizer.param_groups[0]["lr"])
    return float(opt.param_groups[0]["lr"])


print(model)
print("Total parameters:", sum(param.numel() for param in model.parameters()))
print("Loss:", criterion)
print("Optimizer:", type(optimizer).__name__)
print("Prepared datasets and dataloaders:")
print("  train batches:", len(train_loader))
print("  val batches:", len(val_loader))
print("  test batches:", len(test_loader))
print("Training artifacts will be saved to:", best_model_path.resolve())
# Out:
# CNNBiMambaAvgPool(
#   (feature_extractor): CNNFeatureExtractor(
#     (block1): ConvBNAct(
#       (conv): Conv1d(10, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#       (bn): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): SiLU()
#       (drop): Dropout(p=0.15, inplace=False)
#     )
#     (res1): Conv1d(10, 32, kernel_size=(1,), stride=(1,))
#     (pool1): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (block2): ConvBNAct(
#       (conv): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#       (bn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): SiLU()
#       (drop): Dropout(p=0.15, inplace=False)
#     )
#     (res2): Conv1d(32, 64, kernel_size=(1,), stride=(1,))
#     (pool2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (mamba_blocks): ModuleList(
#     (0): MambaBlock(
#       (norm1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       (ssm): BidirectionalMambaLayer(
#         (forward_mamba): MambaS6Layer(
#           (in_proj): Linear(in_features=64, out_features=256, bias=False)
#           (conv1d): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,), groups=128)
#           (x_proj): Linear(in_features=128, out_features=160, bias=False)
#           (dt_proj): Linear(in_features=128, out_features=128, bias=True)
#           (out_proj): Linear(in_features=128, out_features=64, bias=False)
#         )
#         (backward_mamba): MambaS6Layer(
#           (in_proj): Linear(in_features=64, out_features=256, bias=False)
#           (conv1d): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,), groups=128)
#           (x_proj): Linear(in_features=128, out_features=160, bias=False)
#           (dt_proj): Linear(in_features=128, out_features=128, bias=True)
#           (out_proj): Linear(in_features=128, out_features=64, bias=False)
#         )
#         (fusion): Sequential(
#           (0): Linear(in_features=128, out_features=128, bias=True)
#           (1): GLU(dim=-1)
#           (2): Dropout(p=0.2, inplace=False)
#         )
#       )
#       (drop1): Dropout(p=0.2, inplace=False)
#       (drop_path1): DropPath()
#       (norm2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       (ffn): Sequential(
#         (0): Linear(in_features=64, out_features=128, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.2, inplace=False)
#         (3): Linear(in_features=128, out_features=64, bias=True)
#       )
#       (drop2): Dropout(p=0.2, inplace=False)
#       (drop_path2): DropPath()
#     )
#   )
#   (post_mamba_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   (feature_dropout): Dropout1d(p=0.1, inplace=False)
#   (classifier): Sequential(
#     (0): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=64, out_features=96, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.35, inplace=False)
#     (4): Linear(in_features=96, out_features=8, bias=True)
#   )
# )
# Total parameters: 179112
# Loss: CrossEntropyLoss()
# Optimizer: SAM
# Prepared datasets and dataloaders:
#   train batches: 35
#   val batches: 8
#   test batches: 8
# Training artifacts will be saved to: /home/ronghanj/dev/network-traffic-classification/training/models/huawei_cnn_bimamba_avgpool_best.pt

# %%
history = {"train_loss": [], "train_acc": [], "val_loss": [], "val_acc": []}
best_metric_name = str(CONFIG["best_metric"])
best_val_acc = -1.0
best_val_loss = float("inf")
early_stop_patience = int(CONFIG["early_stop_patience"])
early_stop_counter = 0
num_epochs = int(CONFIG["epochs"])
report_clean_train = bool(CONFIG.get("report_clean_train_metrics", True))

use_ema = bool(CONFIG.get("use_ema", False))
ema = ModelEMA(model, decay=float(CONFIG.get("ema_decay", 0.999))) if use_ema else None
eval_with_ema = bool(CONFIG.get("eval_with_ema", False))
save_ema_ckpt = bool(CONFIG.get("save_ema_checkpoint", True))

for epoch in range(1, num_epochs + 1):
    train_loss_aug, _ = run_epoch(
        model,
        train_loader,
        criterion,
        optimizer=optimizer,
        apply_augment=True,
        apply_mixup=True,
        ema=ema,
    )

    if report_clean_train:
        train_loss, train_acc = run_epoch(
            model,
            train_loader,
            criterion,
            optimizer=None,
            apply_augment=False,
            apply_mixup=False,
            ema=None,
        )
    else:
        train_loss, train_acc = train_loss_aug, float("nan")

    if eval_with_ema and ema is not None:
        ema.apply_shadow(model)
        val_loss, val_acc = run_epoch(
            model,
            val_loader,
            criterion,
            optimizer=None,
            apply_augment=False,
            apply_mixup=False,
            ema=None,
        )
        ema.restore(model)
    else:
        val_loss, val_acc = run_epoch(
            model,
            val_loader,
            criterion,
            optimizer=None,
            apply_augment=False,
            apply_mixup=False,
            ema=None,
        )

    scheduler.step(val_loss)

    history["train_loss"].append(train_loss)
    history["train_acc"].append(train_acc)
    history["val_loss"].append(val_loss)
    history["val_acc"].append(val_acc)

    current_lr = get_current_lr(optimizer)
    print(
        f"Epoch {epoch:03d}/{num_epochs} | "
        f"lr={current_lr:.6f} | "
        f"train_loss={train_loss:.4f} train_acc={train_acc:.4f} | "
        f"val_loss={val_loss:.4f} val_acc={val_acc:.4f}"
    )

    if best_metric_name == "val_loss":
        is_better = val_loss < best_val_loss
    else:
        is_better = val_acc > best_val_acc

    if is_better:
        best_val_acc = val_acc
        best_val_loss = val_loss
        early_stop_counter = 0

        if save_ema_ckpt and ema is not None:
            ema.apply_shadow(model)
            torch.save(model.state_dict(), best_model_path)
            ema.restore(model)
        else:
            torch.save(model.state_dict(), best_model_path)

        print(
            f"Saved best model to {best_model_path} "
            f"(val_loss={best_val_loss:.4f}, val_acc={best_val_acc:.4f})"
        )
    else:
        early_stop_counter += 1
        if early_stop_counter >= early_stop_patience:
            print("Early stopping triggered.")
            break
# Out:
# Epoch 001/120 | lr=0.000600 | train_loss=1.7777 train_acc=0.3837 | val_loss=2.0385 val_acc=0.1705
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=2.0385, val_acc=0.1705)
# Epoch 002/120 | lr=0.000600 | train_loss=1.6582 train_acc=0.4096 | val_loss=2.0263 val_acc=0.1892
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=2.0263, val_acc=0.1892)
# Epoch 003/120 | lr=0.000600 | train_loss=1.5683 train_acc=0.4020 | val_loss=2.0132 val_acc=0.1913
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=2.0132, val_acc=0.1913)
# Epoch 004/120 | lr=0.000600 | train_loss=1.4993 train_acc=0.4274 | val_loss=2.0011 val_acc=0.2640
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=2.0011, val_acc=0.2640)
# Epoch 005/120 | lr=0.000600 | train_loss=1.4196 train_acc=0.5306 | val_loss=1.9949 val_acc=0.2453
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.9949, val_acc=0.2453)
# Epoch 006/120 | lr=0.000600 | train_loss=1.3561 train_acc=0.5712 | val_loss=1.9799 val_acc=0.2620
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.9799, val_acc=0.2620)
# Epoch 007/120 | lr=0.000600 | train_loss=1.2989 train_acc=0.6230 | val_loss=1.9642 val_acc=0.2973
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.9642, val_acc=0.2973)
# Epoch 008/120 | lr=0.000600 | train_loss=1.2232 train_acc=0.6516 | val_loss=1.9560 val_acc=0.3202
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.9560, val_acc=0.3202)
# Epoch 009/120 | lr=0.000600 | train_loss=1.1853 train_acc=0.6990 | val_loss=1.9414 val_acc=0.3222
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.9414, val_acc=0.3222)
# Epoch 010/120 | lr=0.000600 | train_loss=1.1360 train_acc=0.6914 | val_loss=1.9241 val_acc=0.3430
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.9241, val_acc=0.3430)
# Epoch 011/120 | lr=0.000600 | train_loss=1.0933 train_acc=0.7383 | val_loss=1.9112 val_acc=0.3472
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.9112, val_acc=0.3472)
# Epoch 012/120 | lr=0.000600 | train_loss=1.1281 train_acc=0.7329 | val_loss=1.8877 val_acc=0.3597
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.8877, val_acc=0.3597)
# Epoch 013/120 | lr=0.000600 | train_loss=1.0744 train_acc=0.7767 | val_loss=1.8707 val_acc=0.3784
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.8707, val_acc=0.3784)
# Epoch 014/120 | lr=0.000600 | train_loss=1.1253 train_acc=0.7151 | val_loss=1.8509 val_acc=0.3929
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.8509, val_acc=0.3929)
# Epoch 015/120 | lr=0.000600 | train_loss=1.1428 train_acc=0.7034 | val_loss=1.8308 val_acc=0.4054
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.8308, val_acc=0.4054)
# Epoch 016/120 | lr=0.000600 | train_loss=1.1158 train_acc=0.6784 | val_loss=1.8173 val_acc=0.4387
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.8173, val_acc=0.4387)
# Epoch 017/120 | lr=0.000600 | train_loss=1.0913 train_acc=0.7142 | val_loss=1.8138 val_acc=0.4470
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.8138, val_acc=0.4470)
# Epoch 018/120 | lr=0.000600 | train_loss=1.0988 train_acc=0.7218 | val_loss=1.8062 val_acc=0.4657
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.8062, val_acc=0.4657)
# Epoch 019/120 | lr=0.000600 | train_loss=1.0533 train_acc=0.7271 | val_loss=1.7645 val_acc=0.4033
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.7645, val_acc=0.4033)
# Epoch 020/120 | lr=0.000600 | train_loss=1.0636 train_acc=0.7119 | val_loss=1.7454 val_acc=0.3846
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.7454, val_acc=0.3846)
# Epoch 021/120 | lr=0.000600 | train_loss=1.1017 train_acc=0.6391 | val_loss=1.7351 val_acc=0.3909
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.7351, val_acc=0.3909)
# Epoch 022/120 | lr=0.000600 | train_loss=1.0628 train_acc=0.6967 | val_loss=1.7105 val_acc=0.4241
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.7105, val_acc=0.4241)
# Epoch 023/120 | lr=0.000600 | train_loss=1.1202 train_acc=0.5931 | val_loss=1.6833 val_acc=0.4553
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.6833, val_acc=0.4553)
# Epoch 024/120 | lr=0.000600 | train_loss=1.0572 train_acc=0.7401 | val_loss=1.6341 val_acc=0.4532
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.6341, val_acc=0.4532)
# Epoch 025/120 | lr=0.000600 | train_loss=1.0284 train_acc=0.7356 | val_loss=1.6197 val_acc=0.4844
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.6197, val_acc=0.4844)
# Epoch 026/120 | lr=0.000600 | train_loss=1.0463 train_acc=0.7655 | val_loss=1.5940 val_acc=0.4657
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.5940, val_acc=0.4657)
# Epoch 027/120 | lr=0.000600 | train_loss=1.0303 train_acc=0.7298 | val_loss=1.5662 val_acc=0.4844
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.5662, val_acc=0.4844)
# Epoch 028/120 | lr=0.000600 | train_loss=1.0051 train_acc=0.7682 | val_loss=1.5551 val_acc=0.5489
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.5551, val_acc=0.5489)
# Epoch 029/120 | lr=0.000600 | train_loss=1.0089 train_acc=0.7829 | val_loss=1.5563 val_acc=0.5946
# Epoch 030/120 | lr=0.000600 | train_loss=0.9845 train_acc=0.7834 | val_loss=1.5071 val_acc=0.5281
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.5071, val_acc=0.5281)
# Epoch 031/120 | lr=0.000600 | train_loss=1.0168 train_acc=0.8209 | val_loss=1.5007 val_acc=0.6133
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.5007, val_acc=0.6133)
# Epoch 032/120 | lr=0.000600 | train_loss=0.9899 train_acc=0.8200 | val_loss=1.4909 val_acc=0.6341
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.4909, val_acc=0.6341)
# Epoch 033/120 | lr=0.000600 | train_loss=1.0038 train_acc=0.8120 | val_loss=1.4601 val_acc=0.5696
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.4601, val_acc=0.5696)
# Epoch 034/120 | lr=0.000600 | train_loss=1.0007 train_acc=0.7838 | val_loss=1.4401 val_acc=0.6507
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.4401, val_acc=0.6507)
# Epoch 035/120 | lr=0.000600 | train_loss=0.9865 train_acc=0.8571 | val_loss=1.4156 val_acc=0.5925
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.4156, val_acc=0.5925)
# Epoch 036/120 | lr=0.000600 | train_loss=0.9871 train_acc=0.8620 | val_loss=1.3895 val_acc=0.6653
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.3895, val_acc=0.6653)
# Epoch 037/120 | lr=0.000600 | train_loss=0.9721 train_acc=0.8799 | val_loss=1.3573 val_acc=0.6279
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.3573, val_acc=0.6279)
# Epoch 038/120 | lr=0.000600 | train_loss=0.9708 train_acc=0.8544 | val_loss=1.3325 val_acc=0.6861
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.3325, val_acc=0.6861)
# Epoch 039/120 | lr=0.000600 | train_loss=0.9760 train_acc=0.7776 | val_loss=1.3104 val_acc=0.6611
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.3104, val_acc=0.6611)
# Epoch 040/120 | lr=0.000600 | train_loss=0.9588 train_acc=0.8222 | val_loss=1.2838 val_acc=0.6923
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.2838, val_acc=0.6923)
# Epoch 041/120 | lr=0.000600 | train_loss=0.9469 train_acc=0.8164 | val_loss=1.2729 val_acc=0.6798
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.2729, val_acc=0.6798)
# Epoch 042/120 | lr=0.000600 | train_loss=0.9588 train_acc=0.8164 | val_loss=1.2681 val_acc=0.7048
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.2681, val_acc=0.7048)
# Epoch 043/120 | lr=0.000600 | train_loss=0.9714 train_acc=0.7870 | val_loss=1.2658 val_acc=0.7173
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.2658, val_acc=0.7173)
# Epoch 044/120 | lr=0.000600 | train_loss=0.9610 train_acc=0.8245 | val_loss=1.2579 val_acc=0.7173
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.2579, val_acc=0.7173)
# Epoch 045/120 | lr=0.000600 | train_loss=0.9481 train_acc=0.8455 | val_loss=1.2593 val_acc=0.7152
# Epoch 046/120 | lr=0.000600 | train_loss=0.9316 train_acc=0.8437 | val_loss=1.2356 val_acc=0.7484
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.2356, val_acc=0.7484)
# Epoch 047/120 | lr=0.000600 | train_loss=0.9588 train_acc=0.8741 | val_loss=1.2178 val_acc=0.7339
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.2178, val_acc=0.7339)
# Epoch 048/120 | lr=0.000600 | train_loss=0.9343 train_acc=0.8870 | val_loss=1.2228 val_acc=0.7152
# Epoch 049/120 | lr=0.000600 | train_loss=0.9003 train_acc=0.8473 | val_loss=1.1812 val_acc=0.7526
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.1812, val_acc=0.7526)
# Epoch 050/120 | lr=0.000600 | train_loss=0.8371 train_acc=0.8566 | val_loss=1.1720 val_acc=0.7588
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.1720, val_acc=0.7588)
# Epoch 051/120 | lr=0.000600 | train_loss=0.8442 train_acc=0.8727 | val_loss=1.1688 val_acc=0.7588
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.1688, val_acc=0.7588)
# Epoch 052/120 | lr=0.000600 | train_loss=0.8369 train_acc=0.8830 | val_loss=1.1493 val_acc=0.7734
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.1493, val_acc=0.7734)
# Epoch 053/120 | lr=0.000600 | train_loss=0.9120 train_acc=0.9031 | val_loss=1.1483 val_acc=0.7921
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.1483, val_acc=0.7921)
# Epoch 054/120 | lr=0.000600 | train_loss=0.8671 train_acc=0.8959 | val_loss=1.1352 val_acc=0.7963
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.1352, val_acc=0.7963)
# Epoch 055/120 | lr=0.000600 | train_loss=0.9149 train_acc=0.8410 | val_loss=1.1415 val_acc=0.7526
# Epoch 056/120 | lr=0.000600 | train_loss=0.8900 train_acc=0.9165 | val_loss=1.1215 val_acc=0.7484
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.1215, val_acc=0.7484)
# Epoch 057/120 | lr=0.000600 | train_loss=0.8785 train_acc=0.8852 | val_loss=1.1354 val_acc=0.7380
# Epoch 058/120 | lr=0.000600 | train_loss=0.8599 train_acc=0.8629 | val_loss=1.1105 val_acc=0.7464
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.1105, val_acc=0.7464)
# Epoch 059/120 | lr=0.000600 | train_loss=0.8469 train_acc=0.8732 | val_loss=1.1137 val_acc=0.7443
# Epoch 060/120 | lr=0.000600 | train_loss=0.8465 train_acc=0.8745 | val_loss=1.0895 val_acc=0.7464
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.0895, val_acc=0.7464)
# Epoch 061/120 | lr=0.000600 | train_loss=0.8641 train_acc=0.9111 | val_loss=1.0803 val_acc=0.7609
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=1.0803, val_acc=0.7609)
# Epoch 062/120 | lr=0.000600 | train_loss=0.8530 train_acc=0.9330 | val_loss=1.0871 val_acc=0.7360
# Epoch 063/120 | lr=0.000600 | train_loss=0.8542 train_acc=0.9326 | val_loss=0.9927 val_acc=0.8046
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.9927, val_acc=0.8046)
# Epoch 064/120 | lr=0.000600 | train_loss=0.8468 train_acc=0.9393 | val_loss=1.0604 val_acc=0.7713
# Epoch 065/120 | lr=0.000600 | train_loss=0.8484 train_acc=0.9071 | val_loss=1.0497 val_acc=0.7817
# Epoch 066/120 | lr=0.000600 | train_loss=0.8085 train_acc=0.8977 | val_loss=0.9910 val_acc=0.8067
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.9910, val_acc=0.8067)
# Epoch 067/120 | lr=0.000600 | train_loss=0.7982 train_acc=0.8857 | val_loss=1.0309 val_acc=0.7983
# Epoch 068/120 | lr=0.000600 | train_loss=0.8137 train_acc=0.9040 | val_loss=1.0290 val_acc=0.7838
# Epoch 069/120 | lr=0.000600 | train_loss=0.8289 train_acc=0.8973 | val_loss=0.9734 val_acc=0.8087
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.9734, val_acc=0.8087)
# Epoch 070/120 | lr=0.000600 | train_loss=0.8246 train_acc=0.9049 | val_loss=1.0426 val_acc=0.7942
# Epoch 071/120 | lr=0.000600 | train_loss=0.8413 train_acc=0.9424 | val_loss=1.0285 val_acc=0.8087
# Epoch 072/120 | lr=0.000600 | train_loss=0.8500 train_acc=0.9455 | val_loss=1.0020 val_acc=0.8150
# Epoch 073/120 | lr=0.000600 | train_loss=0.8266 train_acc=0.9276 | val_loss=0.9609 val_acc=0.8087
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.9609, val_acc=0.8087)
# Epoch 074/120 | lr=0.000600 | train_loss=0.8055 train_acc=0.9321 | val_loss=1.0054 val_acc=0.7983
# Epoch 075/120 | lr=0.000600 | train_loss=0.8328 train_acc=0.9388 | val_loss=1.0061 val_acc=0.8150
# Epoch 076/120 | lr=0.000600 | train_loss=0.8321 train_acc=0.9321 | val_loss=0.9933 val_acc=0.8295
# Epoch 077/120 | lr=0.000600 | train_loss=0.7823 train_acc=0.9263 | val_loss=0.9886 val_acc=0.8316
# Epoch 078/120 | lr=0.000600 | train_loss=0.7739 train_acc=0.9375 | val_loss=0.9890 val_acc=0.8378
# Epoch 079/120 | lr=0.000600 | train_loss=0.7679 train_acc=0.9536 | val_loss=0.9781 val_acc=0.8441
# Epoch 080/120 | lr=0.000300 | train_loss=0.7651 train_acc=0.9433 | val_loss=0.9722 val_acc=0.8441
# Epoch 081/120 | lr=0.000300 | train_loss=0.7658 train_acc=0.9442 | val_loss=0.9464 val_acc=0.8503
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.9464, val_acc=0.8503)
# Epoch 082/120 | lr=0.000300 | train_loss=0.7635 train_acc=0.9513 | val_loss=0.9181 val_acc=0.8482
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.9181, val_acc=0.8482)
# Epoch 083/120 | lr=0.000300 | train_loss=0.7660 train_acc=0.9611 | val_loss=0.9245 val_acc=0.8565
# Epoch 084/120 | lr=0.000300 | train_loss=0.7502 train_acc=0.9567 | val_loss=0.9115 val_acc=0.8545
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.9115, val_acc=0.8545)
# Epoch 085/120 | lr=0.000300 | train_loss=0.7703 train_acc=0.9522 | val_loss=0.9103 val_acc=0.8628
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.9103, val_acc=0.8628)
# Epoch 086/120 | lr=0.000300 | train_loss=0.7600 train_acc=0.9571 | val_loss=0.9139 val_acc=0.8586
# Epoch 087/120 | lr=0.000300 | train_loss=0.7634 train_acc=0.9603 | val_loss=0.9101 val_acc=0.8565
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.9101, val_acc=0.8565)
# Epoch 088/120 | lr=0.000300 | train_loss=0.7375 train_acc=0.9576 | val_loss=0.8959 val_acc=0.8690
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.8959, val_acc=0.8690)
# Epoch 089/120 | lr=0.000300 | train_loss=0.7336 train_acc=0.9616 | val_loss=0.8960 val_acc=0.8711
# Epoch 090/120 | lr=0.000300 | train_loss=0.7189 train_acc=0.9638 | val_loss=0.8925 val_acc=0.8711
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.8925, val_acc=0.8711)
# Epoch 091/120 | lr=0.000300 | train_loss=0.7210 train_acc=0.9638 | val_loss=0.8969 val_acc=0.8690
# Epoch 092/120 | lr=0.000300 | train_loss=0.7518 train_acc=0.9625 | val_loss=0.8977 val_acc=0.8711
# Epoch 093/120 | lr=0.000300 | train_loss=0.7490 train_acc=0.9678 | val_loss=0.8855 val_acc=0.8711
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.8855, val_acc=0.8711)
# Epoch 094/120 | lr=0.000300 | train_loss=0.7317 train_acc=0.9638 | val_loss=0.8925 val_acc=0.8732
# Epoch 095/120 | lr=0.000300 | train_loss=0.7228 train_acc=0.9643 | val_loss=0.8907 val_acc=0.8711
# Epoch 096/120 | lr=0.000300 | train_loss=0.7370 train_acc=0.9687 | val_loss=0.8880 val_acc=0.8773
# Epoch 097/120 | lr=0.000300 | train_loss=0.7372 train_acc=0.9638 | val_loss=0.8869 val_acc=0.8711
# Epoch 098/120 | lr=0.000300 | train_loss=0.7474 train_acc=0.9544 | val_loss=0.8759 val_acc=0.8753
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.8759, val_acc=0.8753)
# Epoch 099/120 | lr=0.000300 | train_loss=0.7511 train_acc=0.9696 | val_loss=0.8806 val_acc=0.8815
# Epoch 100/120 | lr=0.000300 | train_loss=0.7552 train_acc=0.9625 | val_loss=0.8735 val_acc=0.8794
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.8735, val_acc=0.8794)
# Epoch 101/120 | lr=0.000300 | train_loss=0.7487 train_acc=0.9567 | val_loss=0.8764 val_acc=0.8857
# Epoch 102/120 | lr=0.000300 | train_loss=0.7203 train_acc=0.9705 | val_loss=0.8729 val_acc=0.8857
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.8729, val_acc=0.8857)
# Epoch 103/120 | lr=0.000300 | train_loss=0.7472 train_acc=0.9647 | val_loss=0.8761 val_acc=0.8898
# Epoch 104/120 | lr=0.000300 | train_loss=0.7412 train_acc=0.9669 | val_loss=0.8694 val_acc=0.8919
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.8694, val_acc=0.8919)
# Epoch 105/120 | lr=0.000300 | train_loss=0.7492 train_acc=0.9705 | val_loss=0.8615 val_acc=0.8898
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.8615, val_acc=0.8898)
# Epoch 106/120 | lr=0.000300 | train_loss=0.7409 train_acc=0.9678 | val_loss=0.8655 val_acc=0.8981
# Epoch 107/120 | lr=0.000300 | train_loss=0.7571 train_acc=0.9665 | val_loss=0.8611 val_acc=0.8981
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.8611, val_acc=0.8981)
# Epoch 108/120 | lr=0.000300 | train_loss=0.7469 train_acc=0.9638 | val_loss=0.8614 val_acc=0.9002
# Epoch 109/120 | lr=0.000300 | train_loss=0.7181 train_acc=0.9669 | val_loss=0.8581 val_acc=0.9023
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.8581, val_acc=0.9023)
# Epoch 110/120 | lr=0.000300 | train_loss=0.7086 train_acc=0.9665 | val_loss=0.8513 val_acc=0.9002
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.8513, val_acc=0.9002)
# Epoch 111/120 | lr=0.000300 | train_loss=0.6973 train_acc=0.9732 | val_loss=0.8501 val_acc=0.9023
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.8501, val_acc=0.9023)
# Epoch 112/120 | lr=0.000300 | train_loss=0.7142 train_acc=0.9665 | val_loss=0.8510 val_acc=0.9023
# Epoch 113/120 | lr=0.000300 | train_loss=0.7252 train_acc=0.9638 | val_loss=0.8520 val_acc=0.9023
# Epoch 114/120 | lr=0.000300 | train_loss=0.7424 train_acc=0.9594 | val_loss=0.8517 val_acc=0.9064
# Epoch 115/120 | lr=0.000300 | train_loss=0.7598 train_acc=0.9611 | val_loss=0.8517 val_acc=0.9044
# Epoch 116/120 | lr=0.000300 | train_loss=0.7200 train_acc=0.9634 | val_loss=0.8427 val_acc=0.9023
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.8427, val_acc=0.9023)
# Epoch 117/120 | lr=0.000300 | train_loss=0.7274 train_acc=0.9719 | val_loss=0.8469 val_acc=0.9023
# Epoch 118/120 | lr=0.000300 | train_loss=0.6903 train_acc=0.9732 | val_loss=0.8348 val_acc=0.9044
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.8348, val_acc=0.9044)
# Epoch 119/120 | lr=0.000300 | train_loss=0.6843 train_acc=0.9736 | val_loss=0.8323 val_acc=0.9064
# Saved best model to models/huawei_cnn_bimamba_avgpool_best.pt (val_loss=0.8323, val_acc=0.9064)
# Epoch 120/120 | lr=0.000300 | train_loss=0.7027 train_acc=0.9736 | val_loss=0.8380 val_acc=0.9085

# %%
def resolve_checkpoint_path(path_str):
    checkpoint_path = Path(path_str)
    if checkpoint_path.is_absolute():
        return checkpoint_path.resolve()

    candidates = []
    if Path.cwd().name == "training":
        candidates.append((Path.cwd() / checkpoint_path).resolve())
    elif (Path.cwd() / "training").exists():
        candidates.append((Path.cwd() / "training" / checkpoint_path).resolve())
    candidates.append((Path.cwd() / checkpoint_path).resolve())

    for candidate in candidates:
        if candidate.exists():
            return candidate
    return candidates[0]


def load_checkpoint_state_dict(checkpoint_path, map_location):
    checkpoint = torch.load(checkpoint_path, map_location=map_location)
    if isinstance(checkpoint, dict) and "state_dict" in checkpoint:
        return checkpoint["state_dict"]
    return checkpoint


def profile_model_macs(model_path):
    profile_model = model_builder(
        input_shape=X_train_scaled.shape[1:],
        num_classes=num_classes,
        **CONFIG["model_kwargs"],
    ).cpu()
    profile_model.load_state_dict(load_checkpoint_state_dict(model_path, map_location="cpu"))
    profile_model.eval()

    example_input = torch.randn(1, *X_train_scaled.shape[1:], dtype=torch.float32)
    with profile(activities=[ProfilerActivity.CPU], with_flops=True, record_shapes=False, acc_events=True) as prof:
        with torch.no_grad():
            _ = profile_model(example_input)

    total_flops = sum(getattr(event, "flops", 0) for event in prof.key_averages())
    total_macs = total_flops / 2 if total_flops else float("nan")
    return total_flops, total_macs


eval_model_path = resolve_checkpoint_path(CONFIG["eval_model_path"])
if not eval_model_path.exists():
    raise FileNotFoundError(f"Cannot find checkpoint file: {eval_model_path}")

best_model = model_builder(
    input_shape=X_train_scaled.shape[1:],
    num_classes=num_classes,
    **CONFIG["model_kwargs"],
).to(device)
state_dict = load_checkpoint_state_dict(eval_model_path, map_location=device)
best_model.load_state_dict(state_dict)
best_model.eval()

num_params = sum(param.numel() for param in best_model.parameters())
num_trainable_params = sum(param.numel() for param in best_model.parameters() if param.requires_grad)
total_flops, total_macs = profile_model_macs(eval_model_path)

print(f"Loaded checkpoint: {eval_model_path}")
print(f"Parameters: {num_params:,} ({num_params / 1e6:.3f} M)")
print(f"Trainable parameters: {num_trainable_params:,} ({num_trainable_params / 1e6:.3f} M)")
if np.isfinite(total_macs):
    print(f"Approx. FLOPs per sample: {total_flops:,.0f}")
    print(f"Approx. MACs per sample: {total_macs:,.0f} ({total_macs / 1e6:.3f} M)")
else:
    print("Approx. MACs per sample: unavailable")

test_loss, test_acc = run_epoch(best_model, test_loader, criterion, optimizer=None)
print(f"Test loss: {test_loss:.4f} | Test accuracy: {test_acc:.4f}")

all_preds = []
all_targets = []

with torch.no_grad():
    for xb, yb in test_loader:
        xb = xb.to(device)
        logits = best_model(xb)
        preds = logits.argmax(dim=1).cpu().numpy()

        all_preds.append(preds)
        all_targets.append(yb.numpy())

y_pred = np.concatenate(all_preds)
y_true = np.concatenate(all_targets)

target_names = [str(c) for c in classes]
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=target_names, digits=4))

cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:\n", cm)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax, cmap="Blues", xticks_rotation=45, values_format="d", colorbar=False)
ax.set_title("Confusion Matrix")
fig.tight_layout()
plt.show()

print(f"Best model save path: {best_model_path.resolve()}")
print(f"Evaluation checkpoint path: {eval_model_path}")
# Out:
# Loaded checkpoint: /home/ronghanj/dev/network-traffic-classification/training/models/huawei_cnn_bimamba_avgpool_best.pt
# Parameters: 179,112 (0.179 M)
# Trainable parameters: 179,112 (0.179 M)
# Approx. FLOPs per sample: 82,381,824
# Approx. MACs per sample: 41,190,912 (41.191 M)
# Test loss: 0.8449 | Test accuracy: 0.9146
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#   cloud_game     0.8730    0.9167    0.8943        60
#         live     0.9000    0.9000    0.9000        60
#      meeting     0.9818    0.9000    0.9391        60
#      message     0.9492    0.9333    0.9412        60
#     openlive     1.0000    1.0000    1.0000        60
#   phone_game     0.9322    0.9167    0.9244        60
#  short_video     0.8261    0.9500    0.8837        60
#        video     0.8727    0.8000    0.8348        60
#
#     accuracy                         0.9146       480
#    macro avg     0.9169    0.9146    0.9147       480
# weighted avg     0.9169    0.9146    0.9147       480
#
# Confusion Matrix:
#  [[55  0  0  0  0  0  2  3]
#  [ 1 54  0  0  0  1  2  2]
#  [ 0  1 54  3  0  2  0  0]
#  [ 0  0  0 56  0  1  3  0]
#  [ 0  0  0  0 60  0  0  0]
#  [ 0  3  1  0  0 55  0  1]
#  [ 1  1  0  0  0  0 57  1]
#  [ 6  1  0  0  0  0  5 48]]
# Best model save path: /home/ronghanj/dev/network-traffic-classification/training/models/huawei_cnn_bimamba_avgpool_best.pt
# Evaluation checkpoint path: /home/ronghanj/dev/network-traffic-classification/training/models/huawei_cnn_bimamba_avgpool_best.pt
