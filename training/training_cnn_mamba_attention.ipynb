# %% [markdown]
# # Huawei CNN-Single-Mamba Training
#
# 使用 `datasets/processed/huawei/huawei_5s_1000bins_features.npz` 进行 CNN + 单向 Mamba 训练，包含：
# - 数据集划分 (train/val/test = 0.7/0.15/0.15)
# - 对重尾非负特征先做 log1p，再做 RobustScaler 预处理
# - 训练与评估
# - 默认评估本次训练得到的最优 checkpoint

# %%
import importlib
import random
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from sklearn.metrics import ConfusionMatrixDisplay, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from torch.optim import AdamW
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.profiler import ProfilerActivity, profile
from torch.utils.data import DataLoader, TensorDataset

if (Path.cwd() / "training").exists():
    sys.path.append(str(Path.cwd() / "training"))
elif Path.cwd().name == "training":
    sys.path.append(str(Path.cwd()))

CONFIG = {
    "seed": 42,
    "cuda_device": None,
    "dataset_path": "../datasets/processed/huawei/huawei_5s_1000bins_features.npz",
    "model_module": "cnn_mamba_attention",
    "model_builder": "build_cnn_mamba_attention_model",
    "model_kwargs": {
        "num_mamba_layers": 1,
        "mamba_dropout": 0.20,
        "stem_dropout": 0.15,
        "head_dropout": 0.35,
        "drop_path_rate": 0.15,
    },
    "train_ratio": 0.70,
    "val_ratio": 0.15,
    "test_ratio": 0.15,
    "batch_size": 64,
    "epochs": 120,
    "learning_rate": 6e-4,
    "weight_decay": 3e-4,
    "scheduler_factor": 0.5,
    "scheduler_patience": 6,
    "scheduler_min_lr": 1e-5,
    "early_stop_patience": 18,
    "label_smoothing": 0.04,
    "mixup_alpha": 0.20,
    "mixup_prob": 0.40,
    "input_noise_std": 0.004,
    "time_mask_prob": 0.10,
    "time_mask_ratio": 0.04,
    "grad_clip_norm": 1.0,
    "use_sam": True,
    "sam_rho": 0.05,
    "use_ema": True,
    "ema_decay": 0.999,
    "eval_with_ema": True,
    "save_ema_checkpoint": True,
    "best_metric": "val_loss",
    "report_clean_train_metrics": True,
    "model_save_name": "huawei_cnn_mamba_attention_best.pt",
    "eval_model_path": None,
    "log1p_features": [
        "pkt_count",
        "pkt_len_mean",
        "pkt_len_std",
        "last_pkt_global_iat",
        "uplink_pkt_len_sum",
        "downlink_pkt_len_sum",
        "uplink_pkt_count",
        "downlink_pkt_count",
    ],
}

if not np.isclose(CONFIG["train_ratio"] + CONFIG["val_ratio"] + CONFIG["test_ratio"], 1.0):
    raise ValueError("train_ratio + val_ratio + test_ratio must equal 1.0")

SEED = int(CONFIG["seed"])
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    requested_cuda_device = CONFIG.get("cuda_device")
    if requested_cuda_device is not None:
        requested_cuda_device = int(requested_cuda_device)
        if requested_cuda_device >= torch.cuda.device_count():
            raise ValueError(f"Requested cuda_device={requested_cuda_device}, but only {torch.cuda.device_count()} device(s) are visible")
        torch.cuda.set_device(requested_cuda_device)
    torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
if torch.cuda.is_available():
    print("CUDA device index:", torch.cuda.current_device())
print("Dataset:", CONFIG["dataset_path"])
print("Model:", f"{CONFIG['model_module']}.{CONFIG['model_builder']}")
print("Model kwargs:", CONFIG["model_kwargs"])
if CONFIG["eval_model_path"]:
    print("Evaluation checkpoint override:", CONFIG["eval_model_path"])
else:
    print("Evaluation checkpoint override: None (will use best checkpoint from this run)")
# Out:
# Using device: cuda
# CUDA device index: 0
# Dataset: ../datasets/processed/huawei/huawei_5s_1000bins_features.npz
# Model: cnn_mamba_attention.build_cnn_mamba_attention_model
# Model kwargs: {'num_mamba_layers': 1, 'mamba_dropout': 0.2, 'stem_dropout': 0.15, 'head_dropout': 0.35, 'drop_path_rate': 0.15}
# Evaluation checkpoint override: None (will use best checkpoint from this run)

# %%
data_path = Path(CONFIG["dataset_path"])
if not data_path.exists():
    raise FileNotFoundError(f"Cannot find dataset file: {data_path}")

data = np.load(data_path, allow_pickle=True)
X = data["X"].astype(np.float32)
y = data["y"].astype(np.int64)
classes = data["classes"] if "classes" in data.files else np.unique(y)
feature_names = (
    data["feature_names"].astype(str)
    if "feature_names" in data.files
    else np.array([f"feature_{i}" for i in range(X.shape[-1])], dtype=str)
)

print("X shape:", X.shape)
print("y shape:", y.shape)
print("num classes:", len(classes), classes)
print("feature names:", feature_names.tolist())

test_ratio = float(CONFIG["test_ratio"])
val_ratio = float(CONFIG["val_ratio"])
remaining_ratio = 1.0 - test_ratio
val_ratio_within_temp = val_ratio / remaining_ratio

X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=test_ratio, random_state=SEED, stratify=y
)

X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=val_ratio_within_temp, random_state=SEED, stratify=y_temp
)

print("Train shape:", X_train.shape, y_train.shape)
print("Val shape:", X_val.shape, y_val.shape)
print("Test shape:", X_test.shape, y_test.shape)

num_features = X_train.shape[-1]
feature_name_to_idx = {name: idx for idx, name in enumerate(feature_names.tolist())}
missing_log1p_features = [name for name in CONFIG["log1p_features"] if name not in feature_name_to_idx]
if missing_log1p_features:
    raise ValueError(f"Unknown log1p features: {missing_log1p_features}")

log1p_feature_indices = [feature_name_to_idx[name] for name in CONFIG["log1p_features"]]

def apply_log1p_transform(x3d, feature_indices):
    transformed = x3d.copy()
    if feature_indices:
        transformed[:, :, feature_indices] = np.log1p(np.clip(transformed[:, :, feature_indices], a_min=0.0, a_max=None))
    return transformed.astype(np.float32)

X_train_log = apply_log1p_transform(X_train, log1p_feature_indices)
X_val_log = apply_log1p_transform(X_val, log1p_feature_indices)
X_test_log = apply_log1p_transform(X_test, log1p_feature_indices)

scaler = RobustScaler(with_centering=True, with_scaling=True)
X_train_2d = X_train_log.reshape(-1, num_features)
scaler.fit(X_train_2d)

def apply_scaler(x3d):
    x2d = x3d.reshape(-1, num_features)
    x2d = scaler.transform(x2d)
    return x2d.reshape(x3d.shape).astype(np.float32)

X_train_scaled = apply_scaler(X_train_log)
X_val_scaled = apply_scaler(X_val_log)
X_test_scaled = apply_scaler(X_test_log)

print("Applied log1p to features:", CONFIG["log1p_features"])
print("Scaled train mean (approx):", X_train_scaled.mean(axis=(0, 1)))
# Out:
# X shape: (3200, 1000, 10)
# y shape: (3200,)
# num classes: 8 ['cloud_game' 'live' 'meeting' 'message' 'openlive' 'phone_game'
#  'short_video' 'video']
# feature names: ['pkt_count', 'pkt_len_mean', 'pkt_len_std', 'last_pkt_global_iat', 'time_offset_mean_norm', 'uplink_ratio', 'uplink_pkt_len_sum', 'downlink_pkt_len_sum', 'uplink_pkt_count', 'downlink_pkt_count']
# Train shape: (2239, 1000, 10) (2239,)
# Val shape: (481, 1000, 10) (481,)
# Test shape: (480, 1000, 10) (480,)
# Applied log1p to features: ['pkt_count', 'pkt_len_mean', 'pkt_len_std', 'last_pkt_global_iat', 'uplink_pkt_len_sum', 'downlink_pkt_len_sum', 'uplink_pkt_count', 'downlink_pkt_count']
# Scaled train mean (approx): [0.3640149  1.3131924  0.55895454 0.27521262 0.10122527 0.11323868
#  1.0439136  0.8864544  0.23788728 0.18675824]

# %%
class SAM(torch.optim.Optimizer):
    def __init__(self, params, base_optimizer, rho=0.05, **kwargs):
        if rho < 0.0:
            raise ValueError(f"Invalid rho value: {rho}")
        defaults = dict(rho=rho, **kwargs)
        super().__init__(params, defaults)
        self.base_optimizer = base_optimizer(self.param_groups, **kwargs)
        self.param_groups = self.base_optimizer.param_groups
        self.defaults.update(self.base_optimizer.defaults)

    @torch.no_grad()
    def first_step(self, zero_grad=False):
        grad_norm = self._grad_norm()
        if grad_norm == 0:
            if zero_grad:
                self.zero_grad()
            return
        for group in self.param_groups:
            scale = group["rho"] / (grad_norm + 1e-12)
            for p in group["params"]:
                if p.grad is None:
                    continue
                e_w = p.grad * scale.to(p)
                p.add_(e_w)
                self.state[p]["e_w"] = e_w
        if zero_grad:
            self.zero_grad()

    @torch.no_grad()
    def second_step(self, zero_grad=False):
        for group in self.param_groups:
            for p in group["params"]:
                if p.grad is None:
                    continue
                p.sub_(self.state[p].get("e_w", 0.0))
        self.base_optimizer.step()
        if zero_grad:
            self.zero_grad()

    def _grad_norm(self):
        shared_device = self.param_groups[0]["params"][0].device
        norms = []
        for group in self.param_groups:
            for p in group["params"]:
                if p.grad is not None:
                    norms.append(p.grad.norm(p=2).to(shared_device))
        if not norms:
            return torch.tensor(0.0, device=shared_device)
        return torch.norm(torch.stack(norms), p=2)

num_classes = len(np.unique(y))
model_module = importlib.import_module(CONFIG["model_module"])
model_builder = getattr(model_module, CONFIG["model_builder"])
model = model_builder(
    input_shape=X_train_scaled.shape[1:],
    num_classes=num_classes,
    **CONFIG["model_kwargs"],
).to(device)

criterion = nn.CrossEntropyLoss(label_smoothing=float(CONFIG["label_smoothing"]))

if bool(CONFIG.get("use_sam", False)):
    optimizer = SAM(
        model.parameters(),
        AdamW,
        rho=float(CONFIG["sam_rho"]),
        lr=float(CONFIG["learning_rate"]),
        weight_decay=float(CONFIG["weight_decay"]),
    )
else:
    optimizer = AdamW(
        model.parameters(),
        lr=float(CONFIG["learning_rate"]),
        weight_decay=float(CONFIG["weight_decay"]),
    )

scheduler = ReduceLROnPlateau(
    optimizer,
    mode="min",
    factor=float(CONFIG["scheduler_factor"]),
    patience=int(CONFIG["scheduler_patience"]),
    min_lr=float(CONFIG["scheduler_min_lr"]),
)

num_params = sum(p.numel() for p in model.parameters())
print(model)
print("Total parameters:", num_params)
print("Loss:", criterion)
print("Optimizer:", type(optimizer).__name__)
# Out:
# CNNMambaAttention(
#   (feature_extractor): CNNFeatureExtractor(
#     (block1): ConvBNAct(
#       (conv): Conv1d(10, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#       (bn): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): SiLU()
#       (drop): Dropout(p=0.15, inplace=False)
#     )
#     (res1): Conv1d(10, 32, kernel_size=(1,), stride=(1,))
#     (pool1): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (block2): ConvBNAct(
#       (conv): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#       (bn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): SiLU()
#       (drop): Dropout(p=0.15, inplace=False)
#     )
#     (res2): Conv1d(32, 64, kernel_size=(1,), stride=(1,))
#     (pool2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (mamba_blocks): ModuleList(
#     (0): MambaBlock(
#       (norm1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       (ssm): MambaLayer(
#         (mamba): MambaS6Layer(
#           (in_proj): Linear(in_features=64, out_features=256, bias=False)
#           (conv1d): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,), groups=128)
#           (x_proj): Linear(in_features=128, out_features=160, bias=False)
#           (dt_proj): Linear(in_features=128, out_features=128, bias=True)
#           (out_proj): Linear(in_features=128, out_features=64, bias=False)
#         )
#         (dropout): Dropout(p=0.2, inplace=False)
#       )
#       (drop1): Dropout(p=0.2, inplace=False)
#       (drop_path1): DropPath()
#       (norm2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       (ffn): Sequential(
#         (0): Linear(in_features=64, out_features=128, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.2, inplace=False)
#         (3): Linear(in_features=128, out_features=64, bias=True)
#       )
#       (drop2): Dropout(p=0.2, inplace=False)
#       (drop_path2): DropPath()
#     )
#   )
#   (post_mamba_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   (feature_dropout): Dropout1d(p=0.1, inplace=False)
#   (attention_pool): AttentionPooling1D(
#     (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (score): Sequential(
#       (0): Linear(in_features=64, out_features=64, bias=True)
#       (1): GELU(approximate='none')
#       (2): Dropout(p=0.1, inplace=False)
#       (3): Linear(in_features=64, out_features=1, bias=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=64, out_features=96, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.35, inplace=False)
#     (4): Linear(in_features=96, out_features=8, bias=True)
#   )
# )
# Total parameters: 102697
# Loss: CrossEntropyLoss()
# Optimizer: SAM

# %%
models_dir = Path("models")
models_dir.mkdir(parents=True, exist_ok=True)
best_model_path = models_dir / str(CONFIG["model_save_name"])

train_dataset = TensorDataset(
    torch.from_numpy(X_train_scaled).float(), torch.from_numpy(y_train).long()
)
val_dataset = TensorDataset(
    torch.from_numpy(X_val_scaled).float(), torch.from_numpy(y_val).long()
)
test_dataset = TensorDataset(
    torch.from_numpy(X_test_scaled).float(), torch.from_numpy(y_test).long()
)

batch_size = int(CONFIG["batch_size"])
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

class ModelEMA:
    def __init__(self, model, decay=0.999):
        self.decay = float(decay)
        self.shadow = {}
        self.backup = {}
        for name, param in model.named_parameters():
            if param.requires_grad:
                self.shadow[name] = param.detach().clone()

    @torch.no_grad()
    def update(self, model):
        for name, param in model.named_parameters():
            if not param.requires_grad:
                continue
            self.shadow[name].mul_(self.decay).add_(param.detach(), alpha=1.0 - self.decay)

    @torch.no_grad()
    def apply_shadow(self, model):
        self.backup = {}
        for name, param in model.named_parameters():
            if not param.requires_grad:
                continue
            self.backup[name] = param.detach().clone()
            param.data.copy_(self.shadow[name].data)

    @torch.no_grad()
    def restore(self, model):
        for name, param in model.named_parameters():
            if not param.requires_grad:
                continue
            if name in self.backup:
                param.data.copy_(self.backup[name].data)
        self.backup = {}

def apply_time_mask(xb, mask_prob=0.2, mask_ratio=0.08):
    if mask_prob <= 0 or mask_ratio <= 0:
        return xb
    if np.random.rand() > mask_prob:
        return xb

    bsz, seq_len, _ = xb.shape
    mask_len = max(1, int(seq_len * mask_ratio))
    starts = torch.randint(0, seq_len - mask_len + 1, (bsz,), device=xb.device)

    for i in range(bsz):
        s = starts[i]
        xb[i, s : s + mask_len, :] = 0.0
    return xb

def mixup_batch(xb, yb, alpha=0.2):
    if alpha <= 0:
        return xb, yb, yb, 1.0
    lam = np.random.beta(alpha, alpha)
    index = torch.randperm(xb.size(0), device=xb.device)
    mixed_xb = lam * xb + (1 - lam) * xb[index]
    y_a, y_b = yb, yb[index]
    return mixed_xb, y_a, y_b, lam

def run_epoch(model, loader, criterion, optimizer=None, apply_augment=False, apply_mixup=False, ema=None):
    is_train = optimizer is not None
    model.train() if is_train else model.eval()

    running_loss = 0.0
    correct = 0
    total = 0

    use_sam = is_train and bool(CONFIG.get("use_sam", False)) and hasattr(optimizer, "first_step")

    for xb, yb in loader:
        xb = xb.to(device)
        yb = yb.to(device)
        use_mixup = False

        if is_train:
            optimizer.zero_grad()

            if apply_augment:
                noise_std = float(CONFIG["input_noise_std"])
                if noise_std > 0:
                    xb = xb + torch.randn_like(xb) * noise_std
                xb = apply_time_mask(
                    xb,
                    mask_prob=float(CONFIG["time_mask_prob"]),
                    mask_ratio=float(CONFIG["time_mask_ratio"]),
                )

            if apply_mixup:
                use_mixup = np.random.rand() < float(CONFIG["mixup_prob"])
                if use_mixup:
                    xb, y_a, y_b, lam = mixup_batch(xb, yb, alpha=float(CONFIG["mixup_alpha"]))

        if is_train and use_sam:
            logits = model(xb)
            if use_mixup:
                loss = lam * criterion(logits, y_a) + (1 - lam) * criterion(logits, y_b)
            else:
                loss = criterion(logits, yb)
            loss.backward()

            clip_norm = float(CONFIG["grad_clip_norm"])
            if clip_norm > 0:
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=clip_norm)
            optimizer.first_step(zero_grad=True)

            logits_second = model(xb)
            if use_mixup:
                loss_second = lam * criterion(logits_second, y_a) + (1 - lam) * criterion(logits_second, y_b)
            else:
                loss_second = criterion(logits_second, yb)
            loss_second.backward()

            if clip_norm > 0:
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=clip_norm)
            optimizer.second_step(zero_grad=True)

            logits_for_metrics = logits.detach()
            loss_for_log = loss.detach()
        else:
            with torch.set_grad_enabled(is_train):
                logits = model(xb)
                if is_train and use_mixup:
                    loss = lam * criterion(logits, y_a) + (1 - lam) * criterion(logits, y_b)
                else:
                    loss = criterion(logits, yb)
                if is_train:
                    loss.backward()
                    clip_norm = float(CONFIG["grad_clip_norm"])
                    if clip_norm > 0:
                        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=clip_norm)
                    optimizer.step()

            logits_for_metrics = logits.detach()
            loss_for_log = loss.detach()

        if is_train and ema is not None:
            ema.update(model)

        running_loss += loss_for_log.item() * yb.size(0)
        preds = logits_for_metrics.argmax(dim=1)
        correct += (preds == yb).sum().item()
        total += yb.size(0)

    return running_loss / total, correct / total

def get_current_lr(opt):
    if hasattr(opt, "base_optimizer"):
        return float(opt.base_optimizer.param_groups[0]["lr"])
    return float(opt.param_groups[0]["lr"])

print("Prepared datasets and dataloaders:")
print("  train batches:", len(train_loader))
print("  val batches:", len(val_loader))
print("  test batches:", len(test_loader))
print("Training artifacts will be saved to:", best_model_path.resolve())
# Out:
# Prepared datasets and dataloaders:
#   train batches: 35
#   val batches: 8
#   test batches: 8
# Training artifacts will be saved to: /home/ronghanj/dev/network-traffic-classification/training/models/huawei_cnn_mamba_attention_best.pt

# %%
history = {"train_loss": [], "train_acc": [], "val_loss": [], "val_acc": []}
best_metric_name = str(CONFIG["best_metric"])
best_val_acc = -1.0
best_val_loss = float("inf")
early_stop_patience = int(CONFIG["early_stop_patience"])
early_stop_counter = 0
num_epochs = int(CONFIG["epochs"])
report_clean_train = bool(CONFIG.get("report_clean_train_metrics", True))

use_ema = bool(CONFIG.get("use_ema", False))
ema = ModelEMA(model, decay=float(CONFIG.get("ema_decay", 0.999))) if use_ema else None
eval_with_ema = bool(CONFIG.get("eval_with_ema", False))
save_ema_ckpt = bool(CONFIG.get("save_ema_checkpoint", True))

for epoch in range(1, num_epochs + 1):
    train_loss_aug, _ = run_epoch(
        model,
        train_loader,
        criterion,
        optimizer=optimizer,
        apply_augment=True,
        apply_mixup=True,
        ema=ema,
    )

    if report_clean_train:
        train_loss, train_acc = run_epoch(
            model,
            train_loader,
            criterion,
            optimizer=None,
            apply_augment=False,
            apply_mixup=False,
            ema=None,
        )
    else:
        train_loss, train_acc = train_loss_aug, float("nan")

    if eval_with_ema and ema is not None:
        ema.apply_shadow(model)
        val_loss, val_acc = run_epoch(
            model,
            val_loader,
            criterion,
            optimizer=None,
            apply_augment=False,
            apply_mixup=False,
            ema=None,
        )
        ema.restore(model)
    else:
        val_loss, val_acc = run_epoch(
            model,
            val_loader,
            criterion,
            optimizer=None,
            apply_augment=False,
            apply_mixup=False,
            ema=None,
        )

    scheduler.step(val_loss)

    history["train_loss"].append(train_loss)
    history["train_acc"].append(train_acc)
    history["val_loss"].append(val_loss)
    history["val_acc"].append(val_acc)

    current_lr = get_current_lr(optimizer)
    print(
        f"Epoch {epoch:03d}/{num_epochs} | "
        f"lr={current_lr:.6f} | "
        f"train_loss={train_loss:.4f} train_acc={train_acc:.4f} | "
        f"val_loss={val_loss:.4f} val_acc={val_acc:.4f}"
    )

    if best_metric_name == "val_loss":
        is_better = val_loss < best_val_loss
    else:
        is_better = val_acc > best_val_acc

    if is_better:
        best_val_acc = val_acc
        best_val_loss = val_loss
        early_stop_counter = 0

        if save_ema_ckpt and ema is not None:
            ema.apply_shadow(model)
            torch.save(model.state_dict(), best_model_path)
            ema.restore(model)
        else:
            torch.save(model.state_dict(), best_model_path)

        print(
            f"Saved best model to {best_model_path} "
            f"(val_loss={best_val_loss:.4f}, val_acc={best_val_acc:.4f})"
        )
    else:
        early_stop_counter += 1
        if early_stop_counter >= early_stop_patience:
            print("Early stopping triggered.")
            break
# Out:
# Epoch 001/120 | lr=0.000600 | train_loss=1.7496 train_acc=0.4672 | val_loss=2.0942 val_acc=0.1289
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=2.0942, val_acc=0.1289)
# Epoch 002/120 | lr=0.000600 | train_loss=1.5211 train_acc=0.5248 | val_loss=2.0835 val_acc=0.1268
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=2.0835, val_acc=0.1268)
# Epoch 003/120 | lr=0.000600 | train_loss=1.3304 train_acc=0.6003 | val_loss=2.0762 val_acc=0.1268
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=2.0762, val_acc=0.1268)
# Epoch 004/120 | lr=0.000600 | train_loss=1.1657 train_acc=0.6409 | val_loss=2.0557 val_acc=0.1331
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=2.0557, val_acc=0.1331)
# Epoch 005/120 | lr=0.000600 | train_loss=1.0076 train_acc=0.6820 | val_loss=2.0411 val_acc=0.1476
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=2.0411, val_acc=0.1476)
# Epoch 006/120 | lr=0.000600 | train_loss=0.9259 train_acc=0.7280 | val_loss=2.0161 val_acc=0.2412
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=2.0161, val_acc=0.2412)
# Epoch 007/120 | lr=0.000600 | train_loss=0.8669 train_acc=0.7445 | val_loss=2.0007 val_acc=0.2536
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=2.0007, val_acc=0.2536)
# Epoch 008/120 | lr=0.000600 | train_loss=0.8184 train_acc=0.7539 | val_loss=1.9806 val_acc=0.2848
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.9806, val_acc=0.2848)
# Epoch 009/120 | lr=0.000600 | train_loss=0.7576 train_acc=0.7892 | val_loss=1.9512 val_acc=0.3326
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.9512, val_acc=0.3326)
# Epoch 010/120 | lr=0.000600 | train_loss=0.7159 train_acc=0.8088 | val_loss=1.9321 val_acc=0.3597
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.9321, val_acc=0.3597)
# Epoch 011/120 | lr=0.000600 | train_loss=0.7035 train_acc=0.8088 | val_loss=1.8993 val_acc=0.3971
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.8993, val_acc=0.3971)
# Epoch 012/120 | lr=0.000600 | train_loss=0.6561 train_acc=0.8388 | val_loss=1.8742 val_acc=0.4262
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.8742, val_acc=0.4262)
# Epoch 013/120 | lr=0.000600 | train_loss=0.6277 train_acc=0.8406 | val_loss=1.8563 val_acc=0.4324
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.8563, val_acc=0.4324)
# Epoch 014/120 | lr=0.000600 | train_loss=0.6032 train_acc=0.8504 | val_loss=1.8241 val_acc=0.4324
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.8241, val_acc=0.4324)
# Epoch 015/120 | lr=0.000600 | train_loss=0.6007 train_acc=0.8477 | val_loss=1.7864 val_acc=0.4615
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.7864, val_acc=0.4615)
# Epoch 016/120 | lr=0.000600 | train_loss=0.5616 train_acc=0.8691 | val_loss=1.7650 val_acc=0.4719
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.7650, val_acc=0.4719)
# Epoch 017/120 | lr=0.000600 | train_loss=0.5457 train_acc=0.8754 | val_loss=1.7414 val_acc=0.4719
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.7414, val_acc=0.4719)
# Epoch 018/120 | lr=0.000600 | train_loss=0.5157 train_acc=0.8857 | val_loss=1.6957 val_acc=0.5218
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.6957, val_acc=0.5218)
# Epoch 019/120 | lr=0.000600 | train_loss=0.5212 train_acc=0.8808 | val_loss=1.6712 val_acc=0.5260
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.6712, val_acc=0.5260)
# Epoch 020/120 | lr=0.000600 | train_loss=0.4953 train_acc=0.8910 | val_loss=1.6266 val_acc=0.5405
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.6266, val_acc=0.5405)
# Epoch 021/120 | lr=0.000600 | train_loss=0.4767 train_acc=0.8977 | val_loss=1.5933 val_acc=0.5717
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.5933, val_acc=0.5717)
# Epoch 022/120 | lr=0.000600 | train_loss=0.4891 train_acc=0.8986 | val_loss=1.5765 val_acc=0.5447
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.5765, val_acc=0.5447)
# Epoch 023/120 | lr=0.000600 | train_loss=0.4656 train_acc=0.9084 | val_loss=1.5279 val_acc=0.5717
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.5279, val_acc=0.5717)
# Epoch 024/120 | lr=0.000600 | train_loss=0.4555 train_acc=0.9125 | val_loss=1.5035 val_acc=0.5946
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.5035, val_acc=0.5946)
# Epoch 025/120 | lr=0.000600 | train_loss=0.4447 train_acc=0.9125 | val_loss=1.4742 val_acc=0.6029
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.4742, val_acc=0.6029)
# Epoch 026/120 | lr=0.000600 | train_loss=0.4400 train_acc=0.9125 | val_loss=1.4425 val_acc=0.6091
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.4425, val_acc=0.6091)
# Epoch 027/120 | lr=0.000600 | train_loss=0.4327 train_acc=0.9227 | val_loss=1.3906 val_acc=0.6279
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.3906, val_acc=0.6279)
# Epoch 028/120 | lr=0.000600 | train_loss=0.4180 train_acc=0.9339 | val_loss=1.3594 val_acc=0.6445
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.3594, val_acc=0.6445)
# Epoch 029/120 | lr=0.000600 | train_loss=0.4240 train_acc=0.9236 | val_loss=1.3227 val_acc=0.6570
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.3227, val_acc=0.6570)
# Epoch 030/120 | lr=0.000600 | train_loss=0.4091 train_acc=0.9330 | val_loss=1.2725 val_acc=0.6653
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.2725, val_acc=0.6653)
# Epoch 031/120 | lr=0.000600 | train_loss=0.3983 train_acc=0.9379 | val_loss=1.2484 val_acc=0.6507
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.2484, val_acc=0.6507)
# Epoch 032/120 | lr=0.000600 | train_loss=0.3877 train_acc=0.9415 | val_loss=1.2188 val_acc=0.6715
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.2188, val_acc=0.6715)
# Epoch 033/120 | lr=0.000600 | train_loss=0.3796 train_acc=0.9473 | val_loss=1.1885 val_acc=0.6819
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.1885, val_acc=0.6819)
# Epoch 034/120 | lr=0.000600 | train_loss=0.3790 train_acc=0.9486 | val_loss=1.1488 val_acc=0.7027
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.1488, val_acc=0.7027)
# Epoch 035/120 | lr=0.000600 | train_loss=0.3699 train_acc=0.9509 | val_loss=1.1228 val_acc=0.7173
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.1228, val_acc=0.7173)
# Epoch 036/120 | lr=0.000600 | train_loss=0.3745 train_acc=0.9464 | val_loss=1.0725 val_acc=0.7380
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.0725, val_acc=0.7380)
# Epoch 037/120 | lr=0.000600 | train_loss=0.3718 train_acc=0.9482 | val_loss=1.0371 val_acc=0.7297
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.0371, val_acc=0.7297)
# Epoch 038/120 | lr=0.000600 | train_loss=0.3619 train_acc=0.9540 | val_loss=1.0149 val_acc=0.7547
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=1.0149, val_acc=0.7547)
# Epoch 039/120 | lr=0.000600 | train_loss=0.3527 train_acc=0.9540 | val_loss=0.9758 val_acc=0.7651
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.9758, val_acc=0.7651)
# Epoch 040/120 | lr=0.000600 | train_loss=0.3518 train_acc=0.9509 | val_loss=0.9558 val_acc=0.7568
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.9558, val_acc=0.7568)
# Epoch 041/120 | lr=0.000600 | train_loss=0.3417 train_acc=0.9643 | val_loss=0.9239 val_acc=0.7672
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.9239, val_acc=0.7672)
# Epoch 042/120 | lr=0.000600 | train_loss=0.3345 train_acc=0.9634 | val_loss=0.8898 val_acc=0.7879
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.8898, val_acc=0.7879)
# Epoch 043/120 | lr=0.000600 | train_loss=0.3376 train_acc=0.9611 | val_loss=0.8419 val_acc=0.7983
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.8419, val_acc=0.7983)
# Epoch 044/120 | lr=0.000600 | train_loss=0.3255 train_acc=0.9687 | val_loss=0.8236 val_acc=0.7983
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.8236, val_acc=0.7983)
# Epoch 045/120 | lr=0.000600 | train_loss=0.3250 train_acc=0.9701 | val_loss=0.7814 val_acc=0.8191
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.7814, val_acc=0.8191)
# Epoch 046/120 | lr=0.000600 | train_loss=0.3248 train_acc=0.9687 | val_loss=0.7616 val_acc=0.8150
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.7616, val_acc=0.8150)
# Epoch 047/120 | lr=0.000600 | train_loss=0.3276 train_acc=0.9625 | val_loss=0.7558 val_acc=0.8129
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.7558, val_acc=0.8129)
# Epoch 048/120 | lr=0.000600 | train_loss=0.3092 train_acc=0.9799 | val_loss=0.7313 val_acc=0.8254
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.7313, val_acc=0.8254)
# Epoch 049/120 | lr=0.000600 | train_loss=0.3157 train_acc=0.9701 | val_loss=0.7222 val_acc=0.8254
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.7222, val_acc=0.8254)
# Epoch 050/120 | lr=0.000600 | train_loss=0.3162 train_acc=0.9728 | val_loss=0.6986 val_acc=0.8358
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.6986, val_acc=0.8358)
# Epoch 051/120 | lr=0.000600 | train_loss=0.3221 train_acc=0.9705 | val_loss=0.6764 val_acc=0.8378
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.6764, val_acc=0.8378)
# Epoch 052/120 | lr=0.000600 | train_loss=0.3031 train_acc=0.9763 | val_loss=0.6564 val_acc=0.8462
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.6564, val_acc=0.8462)
# Epoch 053/120 | lr=0.000600 | train_loss=0.2973 train_acc=0.9808 | val_loss=0.6475 val_acc=0.8482
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.6475, val_acc=0.8482)
# Epoch 054/120 | lr=0.000600 | train_loss=0.2993 train_acc=0.9754 | val_loss=0.6181 val_acc=0.8482
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.6181, val_acc=0.8482)
# Epoch 055/120 | lr=0.000600 | train_loss=0.3053 train_acc=0.9745 | val_loss=0.6167 val_acc=0.8545
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.6167, val_acc=0.8545)
# Epoch 056/120 | lr=0.000600 | train_loss=0.2953 train_acc=0.9803 | val_loss=0.6102 val_acc=0.8545
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.6102, val_acc=0.8545)
# Epoch 057/120 | lr=0.000600 | train_loss=0.2910 train_acc=0.9839 | val_loss=0.6100 val_acc=0.8545
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.6100, val_acc=0.8545)
# Epoch 058/120 | lr=0.000600 | train_loss=0.2928 train_acc=0.9812 | val_loss=0.5888 val_acc=0.8628
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.5888, val_acc=0.8628)
# Epoch 059/120 | lr=0.000600 | train_loss=0.2916 train_acc=0.9803 | val_loss=0.5863 val_acc=0.8669
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.5863, val_acc=0.8669)
# Epoch 060/120 | lr=0.000600 | train_loss=0.2888 train_acc=0.9826 | val_loss=0.5809 val_acc=0.8669
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.5809, val_acc=0.8669)
# Epoch 061/120 | lr=0.000600 | train_loss=0.2920 train_acc=0.9795 | val_loss=0.5747 val_acc=0.8711
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.5747, val_acc=0.8711)
# Epoch 062/120 | lr=0.000600 | train_loss=0.2826 train_acc=0.9853 | val_loss=0.5736 val_acc=0.8690
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.5736, val_acc=0.8690)
# Epoch 063/120 | lr=0.000600 | train_loss=0.2804 train_acc=0.9848 | val_loss=0.5556 val_acc=0.8773
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.5556, val_acc=0.8773)
# Epoch 064/120 | lr=0.000600 | train_loss=0.2834 train_acc=0.9812 | val_loss=0.5456 val_acc=0.8815
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.5456, val_acc=0.8815)
# Epoch 065/120 | lr=0.000600 | train_loss=0.2717 train_acc=0.9897 | val_loss=0.5544 val_acc=0.8753
# Epoch 066/120 | lr=0.000600 | train_loss=0.2787 train_acc=0.9888 | val_loss=0.5434 val_acc=0.8773
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.5434, val_acc=0.8773)
# Epoch 067/120 | lr=0.000600 | train_loss=0.2780 train_acc=0.9893 | val_loss=0.5321 val_acc=0.8877
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.5321, val_acc=0.8877)
# Epoch 068/120 | lr=0.000600 | train_loss=0.2828 train_acc=0.9848 | val_loss=0.5314 val_acc=0.8836
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.5314, val_acc=0.8836)
# Epoch 069/120 | lr=0.000600 | train_loss=0.2767 train_acc=0.9870 | val_loss=0.5393 val_acc=0.8773
# Epoch 070/120 | lr=0.000600 | train_loss=0.2724 train_acc=0.9884 | val_loss=0.5370 val_acc=0.8753
# Epoch 071/120 | lr=0.000600 | train_loss=0.2749 train_acc=0.9884 | val_loss=0.5259 val_acc=0.8815
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.5259, val_acc=0.8815)
# Epoch 072/120 | lr=0.000600 | train_loss=0.2644 train_acc=0.9929 | val_loss=0.5300 val_acc=0.8898
# Epoch 073/120 | lr=0.000600 | train_loss=0.2668 train_acc=0.9924 | val_loss=0.5245 val_acc=0.8940
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.5245, val_acc=0.8940)
# Epoch 074/120 | lr=0.000600 | train_loss=0.2719 train_acc=0.9888 | val_loss=0.5274 val_acc=0.8877
# Epoch 075/120 | lr=0.000600 | train_loss=0.2659 train_acc=0.9920 | val_loss=0.5195 val_acc=0.8919
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.5195, val_acc=0.8919)
# Epoch 076/120 | lr=0.000600 | train_loss=0.2627 train_acc=0.9920 | val_loss=0.5129 val_acc=0.8981
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.5129, val_acc=0.8981)
# Epoch 077/120 | lr=0.000600 | train_loss=0.2639 train_acc=0.9924 | val_loss=0.5264 val_acc=0.8919
# Epoch 078/120 | lr=0.000600 | train_loss=0.2610 train_acc=0.9946 | val_loss=0.5166 val_acc=0.8960
# Epoch 079/120 | lr=0.000600 | train_loss=0.2600 train_acc=0.9933 | val_loss=0.5148 val_acc=0.8960
# Epoch 080/120 | lr=0.000600 | train_loss=0.2589 train_acc=0.9951 | val_loss=0.5160 val_acc=0.8960
# Epoch 081/120 | lr=0.000600 | train_loss=0.2590 train_acc=0.9942 | val_loss=0.5120 val_acc=0.9002
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.5120, val_acc=0.9002)
# Epoch 082/120 | lr=0.000600 | train_loss=0.2592 train_acc=0.9955 | val_loss=0.5130 val_acc=0.9044
# Epoch 083/120 | lr=0.000600 | train_loss=0.2571 train_acc=0.9951 | val_loss=0.5047 val_acc=0.9023
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.5047, val_acc=0.9023)
# Epoch 084/120 | lr=0.000600 | train_loss=0.2543 train_acc=0.9955 | val_loss=0.5045 val_acc=0.9085
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.5045, val_acc=0.9085)
# Epoch 085/120 | lr=0.000600 | train_loss=0.2542 train_acc=0.9960 | val_loss=0.5024 val_acc=0.9106
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.5024, val_acc=0.9106)
# Epoch 086/120 | lr=0.000600 | train_loss=0.2505 train_acc=0.9969 | val_loss=0.5045 val_acc=0.9085
# Epoch 087/120 | lr=0.000600 | train_loss=0.2546 train_acc=0.9960 | val_loss=0.4944 val_acc=0.9127
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.4944, val_acc=0.9127)
# Epoch 088/120 | lr=0.000600 | train_loss=0.2516 train_acc=0.9960 | val_loss=0.4977 val_acc=0.9106
# Epoch 089/120 | lr=0.000600 | train_loss=0.2539 train_acc=0.9973 | val_loss=0.4980 val_acc=0.9189
# Epoch 090/120 | lr=0.000600 | train_loss=0.2531 train_acc=0.9978 | val_loss=0.4958 val_acc=0.9148
# Epoch 091/120 | lr=0.000600 | train_loss=0.2552 train_acc=0.9951 | val_loss=0.4930 val_acc=0.9168
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.4930, val_acc=0.9168)
# Epoch 092/120 | lr=0.000600 | train_loss=0.2489 train_acc=0.9973 | val_loss=0.5013 val_acc=0.9085
# Epoch 093/120 | lr=0.000600 | train_loss=0.2487 train_acc=0.9982 | val_loss=0.4964 val_acc=0.9127
# Epoch 094/120 | lr=0.000600 | train_loss=0.2465 train_acc=0.9964 | val_loss=0.4880 val_acc=0.9189
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.4880, val_acc=0.9189)
# Epoch 095/120 | lr=0.000600 | train_loss=0.2519 train_acc=0.9955 | val_loss=0.4930 val_acc=0.9189
# Epoch 096/120 | lr=0.000600 | train_loss=0.2463 train_acc=0.9978 | val_loss=0.4967 val_acc=0.9210
# Epoch 097/120 | lr=0.000600 | train_loss=0.2475 train_acc=0.9973 | val_loss=0.4892 val_acc=0.9210
# Epoch 098/120 | lr=0.000600 | train_loss=0.2471 train_acc=0.9987 | val_loss=0.4919 val_acc=0.9148
# Epoch 099/120 | lr=0.000600 | train_loss=0.2494 train_acc=0.9982 | val_loss=0.4937 val_acc=0.9168
# Epoch 100/120 | lr=0.000600 | train_loss=0.2482 train_acc=0.9982 | val_loss=0.4866 val_acc=0.9168
# Saved best model to models/huawei_cnn_mamba_attention_best.pt (val_loss=0.4866, val_acc=0.9168)
# Epoch 101/120 | lr=0.000600 | train_loss=0.2481 train_acc=0.9982 | val_loss=0.4961 val_acc=0.9168
# Epoch 102/120 | lr=0.000600 | train_loss=0.2466 train_acc=0.9982 | val_loss=0.4938 val_acc=0.9106
# Epoch 103/120 | lr=0.000600 | train_loss=0.2432 train_acc=0.9987 | val_loss=0.4960 val_acc=0.9148
# Epoch 104/120 | lr=0.000600 | train_loss=0.2515 train_acc=0.9978 | val_loss=0.5080 val_acc=0.9085
# Epoch 105/120 | lr=0.000600 | train_loss=0.2434 train_acc=0.9991 | val_loss=0.4927 val_acc=0.9148
# Epoch 106/120 | lr=0.000600 | train_loss=0.2439 train_acc=0.9996 | val_loss=0.4957 val_acc=0.9127
# Epoch 107/120 | lr=0.000300 | train_loss=0.2461 train_acc=0.9996 | val_loss=0.5017 val_acc=0.9168
# Epoch 108/120 | lr=0.000300 | train_loss=0.2414 train_acc=0.9996 | val_loss=0.5016 val_acc=0.9127
# Epoch 109/120 | lr=0.000300 | train_loss=0.2447 train_acc=0.9996 | val_loss=0.5015 val_acc=0.9189
# Epoch 110/120 | lr=0.000300 | train_loss=0.2463 train_acc=0.9991 | val_loss=0.5004 val_acc=0.9189
# Epoch 111/120 | lr=0.000300 | train_loss=0.2395 train_acc=0.9996 | val_loss=0.4996 val_acc=0.9148
# Epoch 112/120 | lr=0.000300 | train_loss=0.2418 train_acc=0.9996 | val_loss=0.5006 val_acc=0.9168
# Epoch 113/120 | lr=0.000300 | train_loss=0.2456 train_acc=0.9996 | val_loss=0.5070 val_acc=0.9168
# Epoch 114/120 | lr=0.000150 | train_loss=0.2426 train_acc=0.9996 | val_loss=0.5095 val_acc=0.9127
# Epoch 115/120 | lr=0.000150 | train_loss=0.2418 train_acc=1.0000 | val_loss=0.5027 val_acc=0.9189
# Epoch 116/120 | lr=0.000150 | train_loss=0.2422 train_acc=0.9996 | val_loss=0.5053 val_acc=0.9189
# Epoch 117/120 | lr=0.000150 | train_loss=0.2412 train_acc=0.9996 | val_loss=0.5045 val_acc=0.9168
# Epoch 118/120 | lr=0.000150 | train_loss=0.2413 train_acc=0.9996 | val_loss=0.5089 val_acc=0.9127
# Early stopping triggered.

# %%
def resolve_checkpoint_path(path_str, default_path=None):
    if path_str is None:
        if default_path is None:
            raise ValueError("Either path_str or default_path must be provided")
        return Path(default_path).resolve()

    checkpoint_path = Path(path_str)
    if checkpoint_path.is_absolute():
        return checkpoint_path.resolve()

    candidates = []
    if Path.cwd().name == "training":
        candidates.append((Path.cwd() / checkpoint_path).resolve())
    elif (Path.cwd() / "training").exists():
        candidates.append((Path.cwd() / "training" / checkpoint_path).resolve())
    candidates.append((Path.cwd() / checkpoint_path).resolve())

    for candidate in candidates:
        if candidate.exists():
            return candidate
    return candidates[0]

def load_checkpoint_state_dict(checkpoint_path, map_location):
    checkpoint = torch.load(checkpoint_path, map_location=map_location)
    if isinstance(checkpoint, dict) and "state_dict" in checkpoint:
        return checkpoint["state_dict"]
    return checkpoint

def profile_model_macs(model_path):
    profile_model = model_builder(
        input_shape=X_train_scaled.shape[1:],
        num_classes=num_classes,
        **CONFIG["model_kwargs"],
    ).cpu()
    profile_model.load_state_dict(load_checkpoint_state_dict(model_path, map_location="cpu"))
    profile_model.eval()

    example_input = torch.randn(1, *X_train_scaled.shape[1:], dtype=torch.float32)
    with profile(activities=[ProfilerActivity.CPU], with_flops=True, record_shapes=False, acc_events=True) as prof:
        with torch.no_grad():
            _ = profile_model(example_input)

    total_flops = sum(getattr(event, "flops", 0) for event in prof.key_averages())
    total_macs = total_flops / 2 if total_flops else float("nan")
    return total_flops, total_macs

eval_model_path = resolve_checkpoint_path(CONFIG["eval_model_path"], default_path=best_model_path)
if not eval_model_path.exists():
    raise FileNotFoundError(f"Cannot find checkpoint file: {eval_model_path}")

best_model = model_builder(
    input_shape=X_train_scaled.shape[1:],
    num_classes=num_classes,
    **CONFIG["model_kwargs"],
).to(device)
state_dict = load_checkpoint_state_dict(eval_model_path, map_location=device)
best_model.load_state_dict(state_dict)
best_model.eval()

num_params = sum(param.numel() for param in best_model.parameters())
num_trainable_params = sum(param.numel() for param in best_model.parameters() if param.requires_grad)
total_flops, total_macs = profile_model_macs(eval_model_path)

print(f"Loaded checkpoint: {eval_model_path}")
print(f"Parameters: {num_params:,} ({num_params / 1e6:.3f} M)")
print(f"Trainable parameters: {num_trainable_params:,} ({num_trainable_params / 1e6:.3f} M)")
if np.isfinite(total_macs):
    print(f"Approx. FLOPs per sample: {total_flops:,.0f}")
    print(f"Approx. MACs per sample: {total_macs:,.0f} ({total_macs / 1e6:.3f} M)")
else:
    print("Approx. MACs per sample: unavailable")

test_loss, test_acc = run_epoch(best_model, test_loader, criterion, optimizer=None)
print(f"Test loss: {test_loss:.4f} | Test accuracy: {test_acc:.4f}")

all_preds = []
all_targets = []

with torch.no_grad():
    for xb, yb in test_loader:
        xb = xb.to(device)
        logits = best_model(xb)
        preds = logits.argmax(dim=1).cpu().numpy()

        all_preds.append(preds)
        all_targets.append(yb.numpy())

y_pred = np.concatenate(all_preds)
y_true = np.concatenate(all_targets)

target_names = [str(c) for c in classes]
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=target_names, digits=4))

cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:\n", cm)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax, cmap="Blues", xticks_rotation=45, values_format="d", colorbar=False)
ax.set_title("Confusion Matrix")
fig.tight_layout()
plt.show()

print(f"Best model save path: {best_model_path.resolve()}")
print(f"Evaluation checkpoint path: {eval_model_path}")
# Out:
# Loaded checkpoint: /home/ronghanj/dev/network-traffic-classification/training/models/huawei_cnn_mamba_attention_best.pt
# Parameters: 102,697 (0.103 M)
# Trainable parameters: 102,697 (0.103 M)
# Approx. FLOPs per sample: 43,357,888
# Approx. MACs per sample: 21,678,944 (21.679 M)
# Test loss: 0.4536 | Test accuracy: 0.9271
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#   cloud_game     0.8286    0.9667    0.8923        60
#         live     0.9322    0.9167    0.9244        60
#      meeting     0.9474    0.9000    0.9231        60
#      message     0.9500    0.9500    0.9500        60
#     openlive     1.0000    1.0000    1.0000        60
#   phone_game     0.9206    0.9667    0.9431        60
#  short_video     0.9298    0.8833    0.9060        60
#        video     0.9259    0.8333    0.8772        60
#
#     accuracy                         0.9271       480
#    macro avg     0.9293    0.9271    0.9270       480
# weighted avg     0.9293    0.9271    0.9270       480
#
# Confusion Matrix:
#  [[58  0  0  0  0  0  0  2]
#  [ 0 55  1  0  0  1  1  2]
#  [ 0  0 54  3  0  3  0  0]
#  [ 0  0  0 57  0  1  2  0]
#  [ 0  0  0  0 60  0  0  0]
#  [ 0  0  2  0  0 58  0  0]
#  [ 7  0  0  0  0  0 53  0]
#  [ 5  4  0  0  0  0  1 50]]
# Best model save path: /home/ronghanj/dev/network-traffic-classification/training/models/huawei_cnn_mamba_attention_best.pt
# Evaluation checkpoint path: /home/ronghanj/dev/network-traffic-classification/training/models/huawei_cnn_mamba_attention_best.pt
