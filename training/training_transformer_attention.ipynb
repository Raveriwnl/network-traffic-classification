# %% [markdown]
# # Huawei Transformer Training
#
# 使用 datasets/processed/huawei/huawei_5s_1000bins_features.npz 进行训练，包含：
# - 数据集划分 (train/val/test = 0.7/0.15/0.15)
# - 对重尾非负特征先做 log1p，再做 RobustScaler 预处理
# - Patch-based Transformer 分类模型训练与评估
# - 最优模型保存到 training/models/

# %%
import importlib
import random
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from sklearn.metrics import ConfusionMatrixDisplay, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from torch.optim import AdamW
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.profiler import ProfilerActivity, profile
from torch.utils.data import DataLoader, TensorDataset

if (Path.cwd() / "training").exists():
    project_root = Path.cwd()
elif Path.cwd().name == "training":
    project_root = Path.cwd().parent
else:
    project_root = Path.cwd()

training_dir = project_root / "training"
if str(training_dir) not in sys.path:
    sys.path.append(str(training_dir))

CONFIG = {
    "seed": 42,
    "cuda_device_index": None,
    "dataset_path": str(project_root / "datasets/processed/huawei/huawei_5s_1000bins_features.npz"),
    "models_dir": str(training_dir / "models"),
    "model_module": "transformer_attention",
    "model_builder": "build_transformer_attention_model",
    "model_kwargs": {
        "d_model": 128,
        "num_heads": 4,
        "num_encoder_layers": 3,
        "ff_multiplier": 4,
        "patch_size": 4,
        "embed_dropout": 0.15,
        "attention_dropout": 0.15,
        "encoder_dropout": 0.20,
        "token_dropout": 0.08,
        "drop_path_rate": 0.10,
        "layer_scale_init": 1e-4,
        "head_dropout": 0.40,
    },
    "train_ratio": 0.70,
    "val_ratio": 0.15,
    "test_ratio": 0.15,
    "batch_size": 32,
    "epochs": 120,
    "learning_rate": 3.5e-4,
    "weight_decay": 1e-3,
    "scheduler_factor": 0.5,
    "scheduler_patience": 8,
    "scheduler_min_lr": 1e-5,
    "early_stop_patience": 20,
    "label_smoothing": 0.06,
    "mixup_alpha": 0.30,
    "mixup_prob": 0.50,
    "input_noise_std": 0.006,
    "time_mask_prob": 0.15,
    "time_mask_ratio": 0.06,
    "grad_clip_norm": 0.8,
    "use_sam": True,
    "sam_rho": 0.05,
    "use_ema": True,
    "ema_decay": 0.999,
    "eval_with_ema": True,
    "save_ema_checkpoint": True,
    "best_metric": "val_loss",
    "report_clean_train_metrics": True,
    "model_save_name": "huawei_transformer_attention_best.pt",
    "eval_model_path": str(training_dir / "models/huawei_transformer_attention_best.pt"),
    "log1p_features": [
        "pkt_count",
        "pkt_len_mean",
        "pkt_len_std",
        "last_pkt_global_iat",
        "uplink_pkt_len_sum",
        "downlink_pkt_len_sum",
        "uplink_pkt_count",
        "downlink_pkt_count",
    ],
}

if not np.isclose(CONFIG["train_ratio"] + CONFIG["val_ratio"] + CONFIG["test_ratio"], 1.0):
    raise ValueError("train_ratio + val_ratio + test_ratio must equal 1.0")

SEED = int(CONFIG["seed"])
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    cuda_device_index = CONFIG.get("cuda_device_index")
    if cuda_device_index is not None:
        torch.cuda.set_device(int(cuda_device_index))
    torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
print("Dataset:", CONFIG["dataset_path"])
print("Model:", f"{CONFIG['model_module']}.{CONFIG['model_builder']}")
print("Model kwargs:", CONFIG["model_kwargs"])
print("Evaluation checkpoint:", CONFIG["eval_model_path"])
print("Generalization config:", {
    "label_smoothing": CONFIG["label_smoothing"],
    "mixup": (CONFIG["mixup_alpha"], CONFIG["mixup_prob"]),
    "noise_std": CONFIG["input_noise_std"],
    "time_mask": (CONFIG["time_mask_prob"], CONFIG["time_mask_ratio"]),
    "sam": (CONFIG["use_sam"], CONFIG["sam_rho"]),
    "ema": (CONFIG["use_ema"], CONFIG["ema_decay"]),
    "report_clean_train_metrics": CONFIG["report_clean_train_metrics"],
    "log1p_features": CONFIG["log1p_features"],
})
# Out:
# Using device: cuda
# Dataset: /home/ronghanj/dev/network-traffic-classification/datasets/processed/huawei/huawei_5s_1000bins_features.npz
# Model: transformer_attention.build_transformer_attention_model
# Model kwargs: {'d_model': 128, 'num_heads': 4, 'num_encoder_layers': 3, 'ff_multiplier': 4, 'patch_size': 4, 'embed_dropout': 0.15, 'attention_dropout': 0.15, 'encoder_dropout': 0.2, 'token_dropout': 0.08, 'drop_path_rate': 0.1, 'layer_scale_init': 0.0001, 'head_dropout': 0.4}
# Evaluation checkpoint: /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt
# Generalization config: {'label_smoothing': 0.06, 'mixup': (0.3, 0.5), 'noise_std': 0.006, 'time_mask': (0.15, 0.06), 'sam': (True, 0.05), 'ema': (True, 0.999), 'report_clean_train_metrics': True, 'log1p_features': ['pkt_count', 'pkt_len_mean', 'pkt_len_std', 'last_pkt_global_iat', 'uplink_pkt_len_sum', 'downlink_pkt_len_sum', 'uplink_pkt_count', 'downlink_pkt_count']}

# %%
data_path = Path(CONFIG["dataset_path"])
if not data_path.exists():
    raise FileNotFoundError(f"Cannot find dataset file: {data_path}")

data = np.load(data_path, allow_pickle=True)
X = data["X"].astype(np.float32)
y = data["y"].astype(np.int64)
classes = data["classes"] if "classes" in data.files else np.unique(y)
feature_names = (
    data["feature_names"].astype(str)
    if "feature_names" in data.files
    else np.array([f"feature_{i}" for i in range(X.shape[-1])], dtype=str)
)

print("X shape:", X.shape)
print("y shape:", y.shape)
print("num classes:", len(classes), classes)
print("feature names:", feature_names.tolist())

test_ratio = float(CONFIG["test_ratio"])
val_ratio = float(CONFIG["val_ratio"])
remaining_ratio = 1.0 - test_ratio
val_ratio_within_temp = val_ratio / remaining_ratio

X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=test_ratio, random_state=SEED, stratify=y
)

X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=val_ratio_within_temp, random_state=SEED, stratify=y_temp
)

print("Train shape:", X_train.shape, y_train.shape)
print("Val shape:", X_val.shape, y_val.shape)
print("Test shape:", X_test.shape, y_test.shape)

num_features = X_train.shape[-1]
feature_name_to_idx = {name: idx for idx, name in enumerate(feature_names.tolist())}
missing_log1p_features = [name for name in CONFIG["log1p_features"] if name not in feature_name_to_idx]
if missing_log1p_features:
    raise ValueError(f"Unknown log1p features: {missing_log1p_features}")

log1p_feature_indices = [feature_name_to_idx[name] for name in CONFIG["log1p_features"]]

def apply_log1p_transform(x3d, feature_indices):
    transformed = x3d.copy()
    if feature_indices:
        transformed[:, :, feature_indices] = np.log1p(
            np.clip(transformed[:, :, feature_indices], a_min=0.0, a_max=None)
        )
    return transformed.astype(np.float32)

X_train_log = apply_log1p_transform(X_train, log1p_feature_indices)
X_val_log = apply_log1p_transform(X_val, log1p_feature_indices)
X_test_log = apply_log1p_transform(X_test, log1p_feature_indices)

scaler = RobustScaler(with_centering=True, with_scaling=True)
X_train_2d = X_train_log.reshape(-1, num_features)
scaler.fit(X_train_2d)

def apply_scaler(x3d):
    x2d = x3d.reshape(-1, num_features)
    x2d = scaler.transform(x2d)
    return x2d.reshape(x3d.shape).astype(np.float32)

X_train_scaled = apply_scaler(X_train_log)
X_val_scaled = apply_scaler(X_val_log)
X_test_scaled = apply_scaler(X_test_log)

print("Applied log1p to features:", CONFIG["log1p_features"])
print("Scaled train mean (approx):", X_train_scaled.mean(axis=(0, 1)))
# Out:
# X shape: (3200, 1000, 10)
# y shape: (3200,)
# num classes: 8 ['cloud_game' 'live' 'meeting' 'message' 'openlive' 'phone_game'
#  'short_video' 'video']
# feature names: ['pkt_count', 'pkt_len_mean', 'pkt_len_std', 'last_pkt_global_iat', 'time_offset_mean_norm', 'uplink_ratio', 'uplink_pkt_len_sum', 'downlink_pkt_len_sum', 'uplink_pkt_count', 'downlink_pkt_count']
# Train shape: (2239, 1000, 10) (2239,)
# Val shape: (481, 1000, 10) (481,)
# Test shape: (480, 1000, 10) (480,)
# Applied log1p to features: ['pkt_count', 'pkt_len_mean', 'pkt_len_std', 'last_pkt_global_iat', 'uplink_pkt_len_sum', 'downlink_pkt_len_sum', 'uplink_pkt_count', 'downlink_pkt_count']
# Scaled train mean (approx): [0.3640149  1.3131924  0.55895454 0.27521262 0.10122527 0.11323868
#  1.0439136  0.8864544  0.23788728 0.18675824]

# %%
class SAM(torch.optim.Optimizer):
    def __init__(self, params, base_optimizer, rho=0.05, **kwargs):
        if rho < 0.0:
            raise ValueError(f"Invalid rho value: {rho}")
        defaults = dict(rho=rho, **kwargs)
        super().__init__(params, defaults)
        self.base_optimizer = base_optimizer(self.param_groups, **kwargs)
        self.param_groups = self.base_optimizer.param_groups
        self.defaults.update(self.base_optimizer.defaults)

    @torch.no_grad()
    def first_step(self, zero_grad=False):
        grad_norm = self._grad_norm()
        if grad_norm == 0:
            if zero_grad:
                self.zero_grad()
            return
        for group in self.param_groups:
            scale = group["rho"] / (grad_norm + 1e-12)
            for p in group["params"]:
                if p.grad is None:
                    continue
                e_w = p.grad * scale.to(p)
                p.add_(e_w)
                self.state[p]["e_w"] = e_w
        if zero_grad:
            self.zero_grad()

    @torch.no_grad()
    def second_step(self, zero_grad=False):
        for group in self.param_groups:
            for p in group["params"]:
                if p.grad is None:
                    continue
                p.sub_(self.state[p].get("e_w", 0.0))
        self.base_optimizer.step()
        if zero_grad:
            self.zero_grad()

    @torch.no_grad()
    def step(self, closure=None):
        if closure is None:
            raise RuntimeError("SAM requires closure-based step, use first_step/second_step.")
        loss = closure()
        self.first_step(zero_grad=True)
        closure()
        self.second_step()
        return loss

    def _grad_norm(self):
        shared_device = self.param_groups[0]["params"][0].device
        norms = []
        for group in self.param_groups:
            for p in group["params"]:
                if p.grad is not None:
                    norms.append(p.grad.norm(p=2).to(shared_device))
        if not norms:
            return torch.tensor(0.0, device=shared_device)
        return torch.norm(torch.stack(norms), p=2)

num_classes = len(np.unique(y))
model_module = importlib.import_module(CONFIG["model_module"])
model_module = importlib.reload(model_module)
model_builder = getattr(model_module, CONFIG["model_builder"])
model = model_builder(
    input_shape=X_train_scaled.shape[1:],
    num_classes=num_classes,
    **CONFIG["model_kwargs"],
).to(device)

criterion = nn.CrossEntropyLoss(label_smoothing=float(CONFIG["label_smoothing"]))

if bool(CONFIG.get("use_sam", False)):
    optimizer = SAM(
        model.parameters(),
        AdamW,
        rho=float(CONFIG["sam_rho"]),
        lr=float(CONFIG["learning_rate"]),
        weight_decay=float(CONFIG["weight_decay"]),
    )
else:
    optimizer = AdamW(
        model.parameters(),
        lr=float(CONFIG["learning_rate"]),
        weight_decay=float(CONFIG["weight_decay"]),
    )

scheduler = ReduceLROnPlateau(
    optimizer,
    mode="min",
    factor=float(CONFIG["scheduler_factor"]),
    patience=int(CONFIG["scheduler_patience"]),
    min_lr=float(CONFIG["scheduler_min_lr"]),
)

num_params = sum(p.numel() for p in model.parameters())
print(model)
print("Total parameters:", num_params)
print("Loss:", criterion)
print("Optimizer:", type(optimizer).__name__)
# Out:
# TransformerAttention(
#   (patch_embed): PatchEmbedding1D(
#     (proj): Conv1d(10, 128, kernel_size=(4,), stride=(4,))
#     (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (drop): Dropout(p=0.15, inplace=False)
#   )
#   (token_dropout): TokenDropout()
#   (encoder): ModuleList(
#     (0-2): 3 x TransformerBlock(
#       (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#       )
#       (attn_dropout): Dropout(p=0.2, inplace=False)
#       (drop_path1): DropPath()
#       (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=128, out_features=512, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.2, inplace=False)
#         (3): Linear(in_features=512, out_features=128, bias=True)
#         (4): Dropout(p=0.2, inplace=False)
#       )
#       (drop_path2): DropPath()
#     )
#   )
#   (post_encoder_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (classifier): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.4, inplace=False)
#     (4): Linear(in_features=128, out_features=8, bias=True)
#   )
# )
# Total parameters: 651400
# Loss: CrossEntropyLoss()
# Optimizer: SAM

# %%
models_dir = Path(CONFIG["models_dir"])
models_dir.mkdir(parents=True, exist_ok=True)
best_model_path = models_dir / str(CONFIG["model_save_name"])

train_dataset = TensorDataset(
    torch.from_numpy(X_train_scaled).float(), torch.from_numpy(y_train).long()
)
val_dataset = TensorDataset(
    torch.from_numpy(X_val_scaled).float(), torch.from_numpy(y_val).long()
)
test_dataset = TensorDataset(
    torch.from_numpy(X_test_scaled).float(), torch.from_numpy(y_test).long()
)

batch_size = int(CONFIG["batch_size"])
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

class ModelEMA:
    def __init__(self, model, decay=0.999):
        self.decay = float(decay)
        self.shadow = {}
        self.backup = {}
        for name, param in model.named_parameters():
            if param.requires_grad:
                self.shadow[name] = param.detach().clone()

    @torch.no_grad()
    def update(self, model):
        for name, param in model.named_parameters():
            if not param.requires_grad:
                continue
            self.shadow[name].mul_(self.decay).add_(param.detach(), alpha=1.0 - self.decay)

    @torch.no_grad()
    def apply_shadow(self, model):
        self.backup = {}
        for name, param in model.named_parameters():
            if not param.requires_grad:
                continue
            self.backup[name] = param.detach().clone()
            param.data.copy_(self.shadow[name].data)

    @torch.no_grad()
    def restore(self, model):
        for name, param in model.named_parameters():
            if not param.requires_grad:
                continue
            if name in self.backup:
                param.data.copy_(self.backup[name].data)
        self.backup = {}

def apply_time_mask(xb, mask_prob=0.2, mask_ratio=0.08):
    if mask_prob <= 0 or mask_ratio <= 0:
        return xb
    if np.random.rand() > mask_prob:
        return xb

    bsz, seq_len, _ = xb.shape
    mask_len = max(1, int(seq_len * mask_ratio))
    starts = torch.randint(0, seq_len - mask_len + 1, (bsz,), device=xb.device)

    for i in range(bsz):
        s = starts[i]
        xb[i, s : s + mask_len, :] = 0.0
    return xb

def mixup_batch(xb, yb, alpha=0.2):
    if alpha <= 0:
        return xb, yb, yb, 1.0
    lam = np.random.beta(alpha, alpha)
    index = torch.randperm(xb.size(0), device=xb.device)
    mixed_xb = lam * xb + (1 - lam) * xb[index]
    y_a, y_b = yb, yb[index]
    return mixed_xb, y_a, y_b, lam

def run_epoch(model, loader, criterion, optimizer=None, apply_augment=False, apply_mixup=False, ema=None):
    is_train = optimizer is not None
    model.train() if is_train else model.eval()

    running_loss = 0.0
    correct = 0
    total = 0

    use_sam = is_train and bool(CONFIG.get("use_sam", False)) and hasattr(optimizer, "first_step")

    for xb, yb in loader:
        xb = xb.to(device)
        yb = yb.to(device)
        use_mixup = False

        if is_train:
            optimizer.zero_grad()

            if apply_augment:
                noise_std = float(CONFIG["input_noise_std"])
                if noise_std > 0:
                    xb = xb + torch.randn_like(xb) * noise_std
                xb = apply_time_mask(
                    xb,
                    mask_prob=float(CONFIG["time_mask_prob"]),
                    mask_ratio=float(CONFIG["time_mask_ratio"]),
                )

            if apply_mixup:
                use_mixup = np.random.rand() < float(CONFIG["mixup_prob"])
                if use_mixup:
                    xb, y_a, y_b, lam = mixup_batch(xb, yb, alpha=float(CONFIG["mixup_alpha"]))

        if is_train and use_sam:
            logits = model(xb)
            if use_mixup:
                loss = lam * criterion(logits, y_a) + (1 - lam) * criterion(logits, y_b)
            else:
                loss = criterion(logits, yb)
            loss.backward()

            clip_norm = float(CONFIG["grad_clip_norm"])
            if clip_norm > 0:
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=clip_norm)
            optimizer.first_step(zero_grad=True)

            logits_second = model(xb)
            if use_mixup:
                loss_second = lam * criterion(logits_second, y_a) + (1 - lam) * criterion(logits_second, y_b)
            else:
                loss_second = criterion(logits_second, yb)
            loss_second.backward()

            if clip_norm > 0:
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=clip_norm)
            optimizer.second_step(zero_grad=True)

            logits_for_metrics = logits.detach()
            loss_for_log = loss.detach()
        else:
            with torch.set_grad_enabled(is_train):
                logits = model(xb)
                if is_train and use_mixup:
                    loss = lam * criterion(logits, y_a) + (1 - lam) * criterion(logits, y_b)
                else:
                    loss = criterion(logits, yb)
                if is_train:
                    loss.backward()
                    clip_norm = float(CONFIG["grad_clip_norm"])
                    if clip_norm > 0:
                        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=clip_norm)
                    optimizer.step()

            logits_for_metrics = logits.detach()
            loss_for_log = loss.detach()

        if is_train and ema is not None:
            ema.update(model)

        running_loss += loss_for_log.item() * yb.size(0)
        preds = logits_for_metrics.argmax(dim=1)
        correct += (preds == yb).sum().item()
        total += yb.size(0)

    return running_loss / total, correct / total

def get_current_lr(opt):
    if hasattr(opt, "base_optimizer"):
        return float(opt.base_optimizer.param_groups[0]["lr"])
    return float(opt.param_groups[0]["lr"])

print("Prepared datasets and dataloaders:")
print("  train batches:", len(train_loader))
print("  val batches:", len(val_loader))
print("  test batches:", len(test_loader))
print("Training artifacts will be saved to:", best_model_path.resolve())
# Out:
# Prepared datasets and dataloaders:
#   train batches: 70
#   val batches: 16
#   test batches: 15
# Training artifacts will be saved to: /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt

# %%
history = {"train_loss": [], "train_acc": [], "val_loss": [], "val_acc": []}
best_metric_name = str(CONFIG["best_metric"])
best_val_acc = -1.0
best_val_loss = float("inf")
early_stop_patience = int(CONFIG["early_stop_patience"])
early_stop_counter = 0
num_epochs = int(CONFIG["epochs"])
report_clean_train = bool(CONFIG.get("report_clean_train_metrics", True))

use_ema = bool(CONFIG.get("use_ema", False))
ema = ModelEMA(model, decay=float(CONFIG.get("ema_decay", 0.999))) if use_ema else None
eval_with_ema = bool(CONFIG.get("eval_with_ema", False))
save_ema_ckpt = bool(CONFIG.get("save_ema_checkpoint", True))

for epoch in range(1, num_epochs + 1):
    train_loss_aug, _ = run_epoch(
        model,
        train_loader,
        criterion,
        optimizer=optimizer,
        apply_augment=True,
        apply_mixup=True,
        ema=ema,
    )

    if report_clean_train:
        train_loss, train_acc = run_epoch(
            model,
            train_loader,
            criterion,
            optimizer=None,
            apply_augment=False,
            apply_mixup=False,
            ema=None,
        )
    else:
        train_loss, train_acc = train_loss_aug, float("nan")

    if eval_with_ema and ema is not None:
        ema.apply_shadow(model)
        val_loss, val_acc = run_epoch(
            model,
            val_loader,
            criterion,
            optimizer=None,
            apply_augment=False,
            apply_mixup=False,
            ema=None,
        )
        ema.restore(model)
    else:
        val_loss, val_acc = run_epoch(
            model,
            val_loader,
            criterion,
            optimizer=None,
            apply_augment=False,
            apply_mixup=False,
            ema=None,
        )

    scheduler.step(val_loss)

    history["train_loss"].append(train_loss)
    history["train_acc"].append(train_acc)
    history["val_loss"].append(val_loss)
    history["val_acc"].append(val_acc)

    current_lr = get_current_lr(optimizer)
    print(
        f"Epoch {epoch:03d}/{num_epochs} | "
        f"lr={current_lr:.6f} | "
        f"train_loss={train_loss:.4f} train_acc={train_acc:.4f} | "
        f"val_loss={val_loss:.4f} val_acc={val_acc:.4f}"
    )

    if best_metric_name == "val_loss":
        is_better = val_loss < best_val_loss
    else:
        is_better = val_acc > best_val_acc

    if is_better:
        best_val_acc = val_acc
        best_val_loss = val_loss
        early_stop_counter = 0

        if save_ema_ckpt and ema is not None:
            ema.apply_shadow(model)
            torch.save(model.state_dict(), best_model_path)
            ema.restore(model)
        else:
            torch.save(model.state_dict(), best_model_path)

        print(
            f"Saved best model to {best_model_path} "
            f"(val_loss={best_val_loss:.4f}, val_acc={best_val_acc:.4f})"
        )
    else:
        early_stop_counter += 1
        if early_stop_counter >= early_stop_patience:
            print("Early stopping triggered.")
            break
# Out:
# Epoch 001/120 | lr=0.000350 | train_loss=1.8501 train_acc=0.2782 | val_loss=2.0811 val_acc=0.1247
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=2.0811, val_acc=0.1247)
# Epoch 002/120 | lr=0.000350 | train_loss=1.6231 train_acc=0.4176 | val_loss=2.0736 val_acc=0.1247
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=2.0736, val_acc=0.1247)
# Epoch 003/120 | lr=0.000350 | train_loss=1.4463 train_acc=0.5074 | val_loss=2.0606 val_acc=0.1247
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=2.0606, val_acc=0.1247)
# Epoch 004/120 | lr=0.000350 | train_loss=1.3557 train_acc=0.5391 | val_loss=2.0416 val_acc=0.1393
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=2.0416, val_acc=0.1393)
# Epoch 005/120 | lr=0.000350 | train_loss=1.2254 train_acc=0.6119 | val_loss=2.0172 val_acc=0.1622
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=2.0172, val_acc=0.1622)
# Epoch 006/120 | lr=0.000350 | train_loss=1.0800 train_acc=0.6615 | val_loss=1.9869 val_acc=0.2370
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=1.9869, val_acc=0.2370)
# Epoch 007/120 | lr=0.000350 | train_loss=1.0404 train_acc=0.6847 | val_loss=1.9500 val_acc=0.2786
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=1.9500, val_acc=0.2786)
# Epoch 008/120 | lr=0.000350 | train_loss=0.9606 train_acc=0.7191 | val_loss=1.9047 val_acc=0.3139
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=1.9047, val_acc=0.3139)
# Epoch 009/120 | lr=0.000350 | train_loss=0.9194 train_acc=0.7423 | val_loss=1.8504 val_acc=0.3597
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=1.8504, val_acc=0.3597)
# Epoch 010/120 | lr=0.000350 | train_loss=0.8745 train_acc=0.7628 | val_loss=1.7856 val_acc=0.4033
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=1.7856, val_acc=0.4033)
# Epoch 011/120 | lr=0.000350 | train_loss=0.8550 train_acc=0.7673 | val_loss=1.7138 val_acc=0.4678
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=1.7138, val_acc=0.4678)
# Epoch 012/120 | lr=0.000350 | train_loss=0.8266 train_acc=0.7794 | val_loss=1.6381 val_acc=0.5177
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=1.6381, val_acc=0.5177)
# Epoch 013/120 | lr=0.000350 | train_loss=0.7974 train_acc=0.7937 | val_loss=1.5619 val_acc=0.5468
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=1.5619, val_acc=0.5468)
# Epoch 014/120 | lr=0.000350 | train_loss=0.7827 train_acc=0.7928 | val_loss=1.4881 val_acc=0.5884
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=1.4881, val_acc=0.5884)
# Epoch 015/120 | lr=0.000350 | train_loss=0.7605 train_acc=0.8142 | val_loss=1.4172 val_acc=0.6258
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=1.4172, val_acc=0.6258)
# Epoch 016/120 | lr=0.000350 | train_loss=0.7456 train_acc=0.8182 | val_loss=1.3506 val_acc=0.6383
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=1.3506, val_acc=0.6383)
# Epoch 017/120 | lr=0.000350 | train_loss=0.7189 train_acc=0.8254 | val_loss=1.2876 val_acc=0.6528
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=1.2876, val_acc=0.6528)
# Epoch 018/120 | lr=0.000350 | train_loss=0.7052 train_acc=0.8406 | val_loss=1.2290 val_acc=0.6674
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=1.2290, val_acc=0.6674)
# Epoch 019/120 | lr=0.000350 | train_loss=0.6910 train_acc=0.8481 | val_loss=1.1757 val_acc=0.6736
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=1.1757, val_acc=0.6736)
# Epoch 020/120 | lr=0.000350 | train_loss=0.6823 train_acc=0.8566 | val_loss=1.1251 val_acc=0.6819
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=1.1251, val_acc=0.6819)
# Epoch 021/120 | lr=0.000350 | train_loss=0.6571 train_acc=0.8557 | val_loss=1.0803 val_acc=0.7069
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=1.0803, val_acc=0.7069)
# Epoch 022/120 | lr=0.000350 | train_loss=0.6786 train_acc=0.8477 | val_loss=1.0380 val_acc=0.7235
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=1.0380, val_acc=0.7235)
# Epoch 023/120 | lr=0.000350 | train_loss=0.6321 train_acc=0.8772 | val_loss=1.0008 val_acc=0.7277
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=1.0008, val_acc=0.7277)
# Epoch 024/120 | lr=0.000350 | train_loss=0.6492 train_acc=0.8607 | val_loss=0.9675 val_acc=0.7422
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.9675, val_acc=0.7422)
# Epoch 025/120 | lr=0.000350 | train_loss=0.6204 train_acc=0.8781 | val_loss=0.9364 val_acc=0.7609
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.9364, val_acc=0.7609)
# Epoch 026/120 | lr=0.000350 | train_loss=0.6127 train_acc=0.8705 | val_loss=0.9082 val_acc=0.7713
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.9082, val_acc=0.7713)
# Epoch 027/120 | lr=0.000350 | train_loss=0.6179 train_acc=0.8848 | val_loss=0.8826 val_acc=0.7796
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.8826, val_acc=0.7796)
# Epoch 028/120 | lr=0.000350 | train_loss=0.6070 train_acc=0.8781 | val_loss=0.8605 val_acc=0.7817
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.8605, val_acc=0.7817)
# Epoch 029/120 | lr=0.000350 | train_loss=0.5979 train_acc=0.8879 | val_loss=0.8411 val_acc=0.7879
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.8411, val_acc=0.7879)
# Epoch 030/120 | lr=0.000350 | train_loss=0.5880 train_acc=0.8959 | val_loss=0.8245 val_acc=0.7983
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.8245, val_acc=0.7983)
# Epoch 031/120 | lr=0.000350 | train_loss=0.6021 train_acc=0.8812 | val_loss=0.8087 val_acc=0.8004
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.8087, val_acc=0.8004)
# Epoch 032/120 | lr=0.000350 | train_loss=0.5650 train_acc=0.9026 | val_loss=0.7951 val_acc=0.8087
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.7951, val_acc=0.8087)
# Epoch 033/120 | lr=0.000350 | train_loss=0.5890 train_acc=0.8870 | val_loss=0.7818 val_acc=0.8129
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.7818, val_acc=0.8129)
# Epoch 034/120 | lr=0.000350 | train_loss=0.5679 train_acc=0.8977 | val_loss=0.7700 val_acc=0.8129
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.7700, val_acc=0.8129)
# Epoch 035/120 | lr=0.000350 | train_loss=0.5528 train_acc=0.9111 | val_loss=0.7589 val_acc=0.8170
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.7589, val_acc=0.8170)
# Epoch 036/120 | lr=0.000350 | train_loss=0.5422 train_acc=0.9062 | val_loss=0.7496 val_acc=0.8191
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.7496, val_acc=0.8191)
# Epoch 037/120 | lr=0.000350 | train_loss=0.5380 train_acc=0.9125 | val_loss=0.7424 val_acc=0.8233
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.7424, val_acc=0.8233)
# Epoch 038/120 | lr=0.000350 | train_loss=0.5415 train_acc=0.9067 | val_loss=0.7344 val_acc=0.8274
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.7344, val_acc=0.8274)
# Epoch 039/120 | lr=0.000350 | train_loss=0.5250 train_acc=0.9187 | val_loss=0.7276 val_acc=0.8316
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.7276, val_acc=0.8316)
# Epoch 040/120 | lr=0.000350 | train_loss=0.5286 train_acc=0.9098 | val_loss=0.7210 val_acc=0.8399
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.7210, val_acc=0.8399)
# Epoch 041/120 | lr=0.000350 | train_loss=0.5138 train_acc=0.9303 | val_loss=0.7150 val_acc=0.8441
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.7150, val_acc=0.8441)
# Epoch 042/120 | lr=0.000350 | train_loss=0.5369 train_acc=0.9138 | val_loss=0.7104 val_acc=0.8420
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.7104, val_acc=0.8420)
# Epoch 043/120 | lr=0.000350 | train_loss=0.5122 train_acc=0.9263 | val_loss=0.7059 val_acc=0.8441
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.7059, val_acc=0.8441)
# Epoch 044/120 | lr=0.000350 | train_loss=0.5082 train_acc=0.9227 | val_loss=0.7020 val_acc=0.8482
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.7020, val_acc=0.8482)
# Epoch 045/120 | lr=0.000350 | train_loss=0.4998 train_acc=0.9281 | val_loss=0.6981 val_acc=0.8503
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6981, val_acc=0.8503)
# Epoch 046/120 | lr=0.000350 | train_loss=0.4994 train_acc=0.9290 | val_loss=0.6949 val_acc=0.8482
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6949, val_acc=0.8482)
# Epoch 047/120 | lr=0.000350 | train_loss=0.4965 train_acc=0.9268 | val_loss=0.6916 val_acc=0.8482
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6916, val_acc=0.8482)
# Epoch 048/120 | lr=0.000350 | train_loss=0.4957 train_acc=0.9299 | val_loss=0.6885 val_acc=0.8524
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6885, val_acc=0.8524)
# Epoch 049/120 | lr=0.000350 | train_loss=0.4903 train_acc=0.9299 | val_loss=0.6856 val_acc=0.8503
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6856, val_acc=0.8503)
# Epoch 050/120 | lr=0.000350 | train_loss=0.5059 train_acc=0.9236 | val_loss=0.6833 val_acc=0.8524
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6833, val_acc=0.8524)
# Epoch 051/120 | lr=0.000350 | train_loss=0.4770 train_acc=0.9352 | val_loss=0.6814 val_acc=0.8524
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6814, val_acc=0.8524)
# Epoch 052/120 | lr=0.000350 | train_loss=0.4896 train_acc=0.9357 | val_loss=0.6799 val_acc=0.8503
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6799, val_acc=0.8503)
# Epoch 053/120 | lr=0.000350 | train_loss=0.4786 train_acc=0.9402 | val_loss=0.6785 val_acc=0.8503
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6785, val_acc=0.8503)
# Epoch 054/120 | lr=0.000350 | train_loss=0.4562 train_acc=0.9473 | val_loss=0.6774 val_acc=0.8462
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6774, val_acc=0.8462)
# Epoch 055/120 | lr=0.000350 | train_loss=0.4531 train_acc=0.9491 | val_loss=0.6764 val_acc=0.8462
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6764, val_acc=0.8462)
# Epoch 056/120 | lr=0.000350 | train_loss=0.4492 train_acc=0.9469 | val_loss=0.6755 val_acc=0.8462
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6755, val_acc=0.8462)
# Epoch 057/120 | lr=0.000350 | train_loss=0.4511 train_acc=0.9504 | val_loss=0.6749 val_acc=0.8482
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6749, val_acc=0.8482)
# Epoch 058/120 | lr=0.000350 | train_loss=0.4427 train_acc=0.9509 | val_loss=0.6746 val_acc=0.8482
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6746, val_acc=0.8482)
# Epoch 059/120 | lr=0.000350 | train_loss=0.4538 train_acc=0.9473 | val_loss=0.6743 val_acc=0.8482
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6743, val_acc=0.8482)
# Epoch 060/120 | lr=0.000350 | train_loss=0.4317 train_acc=0.9585 | val_loss=0.6743 val_acc=0.8482
# Epoch 061/120 | lr=0.000350 | train_loss=0.4351 train_acc=0.9594 | val_loss=0.6742 val_acc=0.8482
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6742, val_acc=0.8482)
# Epoch 062/120 | lr=0.000350 | train_loss=0.4340 train_acc=0.9589 | val_loss=0.6729 val_acc=0.8482
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6729, val_acc=0.8482)
# Epoch 063/120 | lr=0.000350 | train_loss=0.4244 train_acc=0.9594 | val_loss=0.6721 val_acc=0.8482
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6721, val_acc=0.8482)
# Epoch 064/120 | lr=0.000350 | train_loss=0.4430 train_acc=0.9513 | val_loss=0.6714 val_acc=0.8462
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6714, val_acc=0.8462)
# Epoch 065/120 | lr=0.000350 | train_loss=0.4191 train_acc=0.9652 | val_loss=0.6710 val_acc=0.8462
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6710, val_acc=0.8462)
# Epoch 066/120 | lr=0.000350 | train_loss=0.4339 train_acc=0.9540 | val_loss=0.6708 val_acc=0.8462
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6708, val_acc=0.8462)
# Epoch 067/120 | lr=0.000350 | train_loss=0.4278 train_acc=0.9589 | val_loss=0.6699 val_acc=0.8482
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6699, val_acc=0.8482)
# Epoch 068/120 | lr=0.000350 | train_loss=0.4144 train_acc=0.9625 | val_loss=0.6686 val_acc=0.8524
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6686, val_acc=0.8524)
# Epoch 069/120 | lr=0.000350 | train_loss=0.4048 train_acc=0.9656 | val_loss=0.6677 val_acc=0.8524
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6677, val_acc=0.8524)
# Epoch 070/120 | lr=0.000350 | train_loss=0.4154 train_acc=0.9620 | val_loss=0.6673 val_acc=0.8524
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6673, val_acc=0.8524)
# Epoch 071/120 | lr=0.000350 | train_loss=0.4108 train_acc=0.9656 | val_loss=0.6661 val_acc=0.8524
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6661, val_acc=0.8524)
# Epoch 072/120 | lr=0.000350 | train_loss=0.4042 train_acc=0.9683 | val_loss=0.6653 val_acc=0.8482
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6653, val_acc=0.8482)
# Epoch 073/120 | lr=0.000350 | train_loss=0.4055 train_acc=0.9638 | val_loss=0.6643 val_acc=0.8482
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6643, val_acc=0.8482)
# Epoch 074/120 | lr=0.000350 | train_loss=0.3944 train_acc=0.9719 | val_loss=0.6629 val_acc=0.8482
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6629, val_acc=0.8482)
# Epoch 075/120 | lr=0.000350 | train_loss=0.3921 train_acc=0.9701 | val_loss=0.6618 val_acc=0.8545
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6618, val_acc=0.8545)
# Epoch 076/120 | lr=0.000350 | train_loss=0.3862 train_acc=0.9741 | val_loss=0.6607 val_acc=0.8524
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6607, val_acc=0.8524)
# Epoch 077/120 | lr=0.000350 | train_loss=0.3879 train_acc=0.9719 | val_loss=0.6600 val_acc=0.8524
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6600, val_acc=0.8524)
# Epoch 078/120 | lr=0.000350 | train_loss=0.3852 train_acc=0.9763 | val_loss=0.6592 val_acc=0.8524
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6592, val_acc=0.8524)
# Epoch 079/120 | lr=0.000350 | train_loss=0.3900 train_acc=0.9741 | val_loss=0.6595 val_acc=0.8565
# Epoch 080/120 | lr=0.000350 | train_loss=0.3871 train_acc=0.9719 | val_loss=0.6594 val_acc=0.8607
# Epoch 081/120 | lr=0.000350 | train_loss=0.3944 train_acc=0.9701 | val_loss=0.6595 val_acc=0.8628
# Epoch 082/120 | lr=0.000350 | train_loss=0.3767 train_acc=0.9763 | val_loss=0.6593 val_acc=0.8607
# Epoch 083/120 | lr=0.000350 | train_loss=0.3713 train_acc=0.9799 | val_loss=0.6591 val_acc=0.8628
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6591, val_acc=0.8628)
# Epoch 084/120 | lr=0.000350 | train_loss=0.3735 train_acc=0.9795 | val_loss=0.6588 val_acc=0.8628
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6588, val_acc=0.8628)
# Epoch 085/120 | lr=0.000350 | train_loss=0.3668 train_acc=0.9826 | val_loss=0.6583 val_acc=0.8628
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6583, val_acc=0.8628)
# Epoch 086/120 | lr=0.000350 | train_loss=0.3752 train_acc=0.9808 | val_loss=0.6576 val_acc=0.8669
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6576, val_acc=0.8669)
# Epoch 087/120 | lr=0.000350 | train_loss=0.3732 train_acc=0.9808 | val_loss=0.6571 val_acc=0.8628
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6571, val_acc=0.8628)
# Epoch 088/120 | lr=0.000350 | train_loss=0.3681 train_acc=0.9817 | val_loss=0.6573 val_acc=0.8732
# Epoch 089/120 | lr=0.000350 | train_loss=0.3662 train_acc=0.9830 | val_loss=0.6574 val_acc=0.8711
# Epoch 090/120 | lr=0.000350 | train_loss=0.3616 train_acc=0.9848 | val_loss=0.6572 val_acc=0.8690
# Epoch 091/120 | lr=0.000350 | train_loss=0.3593 train_acc=0.9857 | val_loss=0.6564 val_acc=0.8711
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6564, val_acc=0.8711)
# Epoch 092/120 | lr=0.000350 | train_loss=0.3561 train_acc=0.9879 | val_loss=0.6553 val_acc=0.8690
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6553, val_acc=0.8690)
# Epoch 093/120 | lr=0.000350 | train_loss=0.3555 train_acc=0.9870 | val_loss=0.6548 val_acc=0.8711
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6548, val_acc=0.8711)
# Epoch 094/120 | lr=0.000350 | train_loss=0.3661 train_acc=0.9844 | val_loss=0.6552 val_acc=0.8690
# Epoch 095/120 | lr=0.000350 | train_loss=0.3587 train_acc=0.9848 | val_loss=0.6550 val_acc=0.8690
# Epoch 096/120 | lr=0.000350 | train_loss=0.3533 train_acc=0.9879 | val_loss=0.6550 val_acc=0.8690
# Epoch 097/120 | lr=0.000350 | train_loss=0.3513 train_acc=0.9902 | val_loss=0.6549 val_acc=0.8690
# Epoch 098/120 | lr=0.000350 | train_loss=0.3535 train_acc=0.9875 | val_loss=0.6545 val_acc=0.8690
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6545, val_acc=0.8690)
# Epoch 099/120 | lr=0.000350 | train_loss=0.3569 train_acc=0.9857 | val_loss=0.6549 val_acc=0.8690
# Epoch 100/120 | lr=0.000350 | train_loss=0.3533 train_acc=0.9875 | val_loss=0.6540 val_acc=0.8690
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6540, val_acc=0.8690)
# Epoch 101/120 | lr=0.000350 | train_loss=0.3506 train_acc=0.9893 | val_loss=0.6543 val_acc=0.8690
# Epoch 102/120 | lr=0.000350 | train_loss=0.3514 train_acc=0.9888 | val_loss=0.6540 val_acc=0.8711
# Epoch 103/120 | lr=0.000350 | train_loss=0.3609 train_acc=0.9839 | val_loss=0.6538 val_acc=0.8732
# Saved best model to /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt (val_loss=0.6538, val_acc=0.8732)
# Epoch 104/120 | lr=0.000350 | train_loss=0.3483 train_acc=0.9879 | val_loss=0.6546 val_acc=0.8732
# Epoch 105/120 | lr=0.000350 | train_loss=0.3570 train_acc=0.9857 | val_loss=0.6556 val_acc=0.8732
# Epoch 106/120 | lr=0.000350 | train_loss=0.3495 train_acc=0.9893 | val_loss=0.6561 val_acc=0.8732
# Epoch 107/120 | lr=0.000350 | train_loss=0.3486 train_acc=0.9875 | val_loss=0.6574 val_acc=0.8732
# Epoch 108/120 | lr=0.000350 | train_loss=0.3438 train_acc=0.9915 | val_loss=0.6586 val_acc=0.8753
# Epoch 109/120 | lr=0.000350 | train_loss=0.3515 train_acc=0.9879 | val_loss=0.6601 val_acc=0.8753
# Epoch 110/120 | lr=0.000350 | train_loss=0.3393 train_acc=0.9924 | val_loss=0.6598 val_acc=0.8794
# Epoch 111/120 | lr=0.000350 | train_loss=0.3374 train_acc=0.9924 | val_loss=0.6595 val_acc=0.8773
# Epoch 112/120 | lr=0.000175 | train_loss=0.3416 train_acc=0.9893 | val_loss=0.6603 val_acc=0.8794
# Epoch 113/120 | lr=0.000175 | train_loss=0.3412 train_acc=0.9902 | val_loss=0.6595 val_acc=0.8815
# Epoch 114/120 | lr=0.000175 | train_loss=0.3397 train_acc=0.9906 | val_loss=0.6585 val_acc=0.8857
# Epoch 115/120 | lr=0.000175 | train_loss=0.3375 train_acc=0.9915 | val_loss=0.6581 val_acc=0.8836
# Epoch 116/120 | lr=0.000175 | train_loss=0.3387 train_acc=0.9902 | val_loss=0.6581 val_acc=0.8836
# Epoch 117/120 | lr=0.000175 | train_loss=0.3339 train_acc=0.9924 | val_loss=0.6579 val_acc=0.8836
# Epoch 118/120 | lr=0.000175 | train_loss=0.3334 train_acc=0.9924 | val_loss=0.6578 val_acc=0.8836
# Epoch 119/120 | lr=0.000175 | train_loss=0.3363 train_acc=0.9906 | val_loss=0.6568 val_acc=0.8857
# Epoch 120/120 | lr=0.000175 | train_loss=0.3355 train_acc=0.9911 | val_loss=0.6556 val_acc=0.8857

# %%
def resolve_checkpoint_path(path_str):
    checkpoint_path = Path(path_str)
    if checkpoint_path.is_absolute():
        return checkpoint_path.resolve()

    candidates = [
        (training_dir / checkpoint_path).resolve(),
        (project_root / checkpoint_path).resolve(),
        (Path.cwd() / checkpoint_path).resolve(),
    ]
    for candidate in candidates:
        if candidate.exists():
            return candidate
    return candidates[0]

def load_checkpoint_state_dict(checkpoint_path, map_location):
    checkpoint = torch.load(checkpoint_path, map_location=map_location)
    if isinstance(checkpoint, dict) and "state_dict" in checkpoint:
        return checkpoint["state_dict"]
    return checkpoint

def profile_model_macs(model_path):
    profile_model = model_builder(
        input_shape=X_train_scaled.shape[1:],
        num_classes=num_classes,
        **CONFIG["model_kwargs"],
    ).cpu()
    profile_model.load_state_dict(load_checkpoint_state_dict(model_path, map_location="cpu"))
    profile_model.eval()

    example_input = torch.randn(1, *X_train_scaled.shape[1:], dtype=torch.float32)
    with profile(activities=[ProfilerActivity.CPU], with_flops=True, record_shapes=False, acc_events=True) as prof:
        with torch.no_grad():
            _ = profile_model(example_input)

    total_flops = sum(getattr(event, "flops", 0) for event in prof.key_averages())
    total_macs = total_flops / 2 if total_flops else float("nan")
    return total_flops, total_macs

eval_model_path = resolve_checkpoint_path(CONFIG["eval_model_path"])
if not eval_model_path.exists():
    raise FileNotFoundError(f"Cannot find checkpoint file: {eval_model_path}")

best_model = model_builder(
    input_shape=X_train_scaled.shape[1:],
    num_classes=num_classes,
    **CONFIG["model_kwargs"],
).to(device)
state_dict = load_checkpoint_state_dict(eval_model_path, map_location=device)
best_model.load_state_dict(state_dict)
best_model.eval()

num_params = sum(param.numel() for param in best_model.parameters())
num_trainable_params = sum(param.numel() for param in best_model.parameters() if param.requires_grad)
total_flops, total_macs = profile_model_macs(eval_model_path)

print(f"Loaded checkpoint: {eval_model_path}")
print(f"Parameters: {num_params:,} ({num_params / 1e6:.3f} M)")
print(f"Trainable parameters: {num_trainable_params:,} ({num_trainable_params / 1e6:.3f} M)")
if np.isfinite(total_macs):
    print(f"Approx. FLOPs per sample: {total_flops:,.0f}")
    print(f"Approx. MACs per sample: {total_macs:,.0f} ({total_macs / 1e6:.3f} M)")
else:
    print("Approx. MACs per sample: unavailable")

test_loss, test_acc = run_epoch(best_model, test_loader, criterion, optimizer=None)
print(f"Test loss: {test_loss:.4f} | Test accuracy: {test_acc:.4f}")

all_preds = []
all_targets = []

with torch.no_grad():
    for xb, yb in test_loader:
        xb = xb.to(device)
        logits = best_model(xb)
        preds = logits.argmax(dim=1).cpu().numpy()
        all_preds.append(preds)
        all_targets.append(yb.numpy())

y_pred = np.concatenate(all_preds)
y_true = np.concatenate(all_targets)

target_names = [str(c) for c in classes]
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=target_names, digits=4))

cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:\n", cm)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax, cmap="Blues", xticks_rotation=45, values_format="d", colorbar=False)
ax.set_title("Confusion Matrix")
fig.tight_layout()
plt.show()

print(f"Best model save path: {best_model_path.resolve()}")
print(f"Evaluation checkpoint path: {eval_model_path}")
# Out:
# Loaded checkpoint: /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt
# Parameters: 651,400 (0.651 M)
# Trainable parameters: 651,400 (0.651 M)
# Approx. FLOPs per sample: 393,313,664
# Approx. MACs per sample: 196,656,832 (196.657 M)
# Test loss: 0.5814 | Test accuracy: 0.9062
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#   cloud_game     0.8594    0.9167    0.8871        60
#         live     0.9016    0.9167    0.9091        60
#      meeting     0.8667    0.8667    0.8667        60
#      message     0.9474    0.9000    0.9231        60
#     openlive     1.0000    0.9833    0.9916        60
#   phone_game     0.9153    0.9000    0.9076        60
#  short_video     0.8966    0.8667    0.8814        60
#        video     0.8710    0.9000    0.8852        60
#
#     accuracy                         0.9062       480
#    macro avg     0.9072    0.9062    0.9065       480
# weighted avg     0.9072    0.9062    0.9065       480
#
# Confusion Matrix:
#  [[55  0  1  0  0  0  1  3]
#  [ 3 55  0  0  0  1  0  1]
#  [ 0  2 52  3  0  3  0  0]
#  [ 0  0  3 54  0  1  2  0]
#  [ 0  0  1  0 59  0  0  0]
#  [ 0  3  3  0  0 54  0  0]
#  [ 3  1  0  0  0  0 52  4]
#  [ 3  0  0  0  0  0  3 54]]
# Best model save path: /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt
# Evaluation checkpoint path: /home/ronghanj/dev/network-traffic-classification/training/models/huawei_transformer_attention_best.pt
